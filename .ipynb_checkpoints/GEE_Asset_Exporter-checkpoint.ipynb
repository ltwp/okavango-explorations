# %% [markdown]
# ## GEE Asset Exporter
#
# This script uses the geemap package to export monthly Landsat-derived DSWE products (DSWE mask, QC mask, and RGB of composite) and monthly Sentinel-2 based DSWE products. The code is directed to a GEE asset folder, a study area boundary for clipping, and a local output folder. The code iterates through the assets and exports as .tifs, tiling when needed.
#
# Author: James (Huck) Rees, PhD Student, UC Santa Barbara Geography
#
# Date: October 1st, 2025

# %% [markdown]
# ## Import packages

# %%
import ee
import os
import re
import math
import glob
import rasterio
import geopandas as gpd
from rasterio.merge import merge
from rasterio.mask import mask
import geemap
import tempfile
import shutil

ee.Initialize()

# %% [markdown]
# ## Export monthly Landsat-derived DSWE products

# %%
def get_geometry_area_km2(geom):
    return geom.area().divide(1e6).getInfo()

def tile_geometry(geometry, tile_size_km2):
    area_km2 = get_geometry_area_km2(geometry)
    if area_km2 <= tile_size_km2:
        return [geometry]
    num_tiles = math.ceil(area_km2 / tile_size_km2)
    tile_count = math.ceil(math.sqrt(num_tiles))
    bounds = geometry.bounds().coordinates().getInfo()[0]
    min_lon, min_lat = bounds[0]
    max_lon, max_lat = bounds[2]
    lon_step = (max_lon - min_lon) / tile_count
    lat_step = (max_lat - min_lat) / tile_count
    tiles = []
    for i in range(tile_count):
        for j in range(tile_count):
            tile = ee.Geometry.Rectangle([
                [min_lon + i * lon_step, min_lat + j * lat_step],
                [min_lon + (i + 1) * lon_step, min_lat + (j + 1) * lat_step]
            ])
            tiles.append(tile)
    return tiles

def clip_raster_to_shape(raster_path, shapefile_path):
    gdf = gpd.read_file(shapefile_path)

    with rasterio.open(raster_path) as src:
        if gdf.crs != src.crs:
            gdf = gdf.to_crs(src.crs)

        geoms = [geom.__geo_interface__ for geom in gdf.geometry]
        clipped_image, clipped_transform = mask(src, geoms, crop=True)
        clipped_meta = src.meta.copy()
        clipped_meta.update({
            "height": clipped_image.shape[1],
            "width": clipped_image.shape[2],
            "transform": clipped_transform,
            "nodata": 255,
            "compress": "LZW"
        })

    # Save to temp file first
    with tempfile.NamedTemporaryFile(delete=False, suffix=".tif") as tmpfile:
        temp_path = tmpfile.name

    with rasterio.open(temp_path, "w", **clipped_meta) as dest:
        dest.write(clipped_image)

    # Replace original
    shutil.move(temp_path, raster_path)
    print(f"✅ Clipped raster saved (overwritten): {raster_path}")
    
def stitch_tiles(output_folder, basename, shapefile_path):
    tile_paths = glob.glob(os.path.join(output_folder, f"{basename}_tile_*.tif"))
    if not tile_paths:
        print("No tiles found to stitch.")
        return
    if len(tile_paths) == 1:
        os.rename(tile_paths[0], os.path.join(output_folder, f"{basename}.tif"))
    else:
        srcs = [rasterio.open(p) for p in tile_paths]
        mosaic, transform = merge(srcs)
        for src in srcs:
            src.close()
        mosaic[mosaic == -1] = 0
        meta = srcs[0].meta.copy()
        meta.update({
            "height": mosaic.shape[1],
            "width": mosaic.shape[2],
            "transform": transform,
            "compress": "LZW",
            "nodata": 255,
            "dtype": "uint8"
        })
        out_path = os.path.join(output_folder, f"{basename}.tif")
        with rasterio.open(out_path, "w", **meta) as dest:
            dest.write(mosaic)
        for path in tile_paths:
            os.remove(path)

    # Clip the stitched raster
    clip_raster_to_shape(
        os.path.join(output_folder, f"{basename}.tif"),
        shapefile_path
    )

def export_dswe_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2=3000):
    os.makedirs(local_output_folder, exist_ok=True)
    asset_list = ee.data.listAssets({'parent': asset_root_path})['assets']

    for asset in asset_list:
        asset_id = asset['name']
        basename = asset_id.split('/')[-1]
        match = re.match(r'DSWE_(\d{4})_(\d{2})', basename)
        if not match:
            continue
        year = int(match.group(1))
        if not (start_year <= year <= end_year):
            continue

        print(f"🚀 Processing {basename}")
        image = ee.Image(asset_id).select('dswe').unmask(-1).int8()
        region = image.geometry()
        output_path = os.path.join(local_output_folder, f"{basename}.tif")

        # Try full export
        try:
            geemap.ee_export_image(
                image,
                filename=output_path,
                scale=30,
                region=region.getInfo()['coordinates'],
                file_per_band=False,
                crs='EPSG:4326'
            )
        except Exception as e:
            print(f"⚠️ Failed full export for {basename}: {e}")

        if not os.path.exists(output_path):
            print(f"🔁 Falling back to tiling for {basename}")
            tiles = tile_geometry(region, tile_size_km2)
            for i, tile in enumerate(tiles):
                tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
                try:
                    geemap.ee_export_image(
                        image.clip(tile),
                        filename=tile_path,
                        scale=30,
                        region=tile.getInfo()['coordinates'],
                        file_per_band=False,
                        crs='EPSG:4326'
                    )
                except Exception as te:
                    print(f"❌ Tile {i} failed: {te}")
            stitch_tiles(local_output_folder, basename, shapefile_path)
        else:
            print(f"✅ Successfully exported {basename} (no tiling needed)")
            clip_raster_to_shape(output_path, shapefile_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
export_dswe_assets_tiled(
    asset_root_path="projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/DSWE_Products",
    local_output_folder=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting",
    shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
    start_year=2023,
    end_year=2023,
    tile_size_km2=10000
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 🚀 Processing DSWE_2023_01
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ed1237058594bca930f6c5f609d640f6-234beb85c86bbe4a5f43333c1a8d29ae:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/197290974b5dcb46cda64c47a83707d8-58057bb2d008ab8b8bf592fccca3573c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/99d6e30455e6fd12532d765bf2f3e41f-5280f0af5fe62e7cfb10436dd263679f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e79b0eaf1e95bdade91a74ec5cdffe80-850649cb524d8e0f67126681b961460d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/2f3e60fa00b8049f9a7dd12f37bece29-b71589eb383f960fc1f0d7a75a7d5744:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/cb7fa03caac22c1e1eaca87228f2093b-4b29bf75ba1ff7da0fd46e9290fa2618:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/cc12ae5e7b0028d9af5e8b2540f0e86a-8f07c76180ba4818da03a993dffb9516:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/612b7f6908142a584a99608b01bd5737-572514ac3bd0eab068d13b9c5e61db0f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/59ff3c78372a5f0f48df1b1bca081bc2-b6b943fd6986cf6f83d76223446e1a0f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_8.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01.tif
# 🚀 Processing DSWE_2023_02
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0b3f7d40b1717162a5a27bded983faa2-4d9590a84a044437b88d77e218c613bb:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d6f7730e02043e2d322ec46b23d267be-dd0f1b095ed09052aef263f8171a07b4:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/31e06c8b4e0d71e91f75839ba66369b7-1c9b05faade8948475c73f4435aefca5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ee17dfa62e76bd734fb70f659c10922b-3ac9738150d4cfbf3b1c20aeb01ba612:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/af73e5ba3c6217da4023564d8ce773a7-a02dcad0197761b93c21ef71d75642a2:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f416abc6f862ee51614dc34b56e2f216-6e58788995ed21b686d0e5102d98489a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a2f2bb3a19b397601f8aada435ccac85-a2c27cb7285a2db7782305d745a1cab2:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/36c9c008b4aa5266190dfe4b805199ee-4a5505f291263dcaf770fb702c58f78e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9524580053ac7e5b6d1734c52081d526-89c22d0267783edbb4d63669383c8e5c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_8.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02.tif
# 🚀 Processing DSWE_2023_03
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/eb55c4f53684b623f8bd8496d50372d0-c43ee708ad3cf1cde1cbaf6bf7a3d767:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/42f3dabd71dd85426fa925dccd7a3d2e-666dea9cd47619f99bf3737222cc52c2:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6ee55b1faed4f12c03dcaf024c793086-217a186227a639106d48d061d85f123d:getPixels
# Please wait ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 export_dswe_assets_tiled(
#       2     asset_root_path="projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/DSWE_Products",
#       3     local_output_folder=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting",
#       4     shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
#       5     start_year=2023,
#       6     end_year=2023,
#       7     tile_size_km2=10000
#       8 )
#
# Cell In[5], line 126, in export_dswe_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2)
#     124 tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
#     125 try:
# --> 126     geemap.ee_export_image(
#     127         image.clip(tile),
#     128         filename=tile_path,
#     129         scale=30,
#     130         region=tile.getInfo()['coordinates'],
#     131         file_per_band=False,
#     132         crs='EPSG:4326'
#     133     )
#     134 except Exception as te:
#     135     print(f"❌ Tile {i} failed: {te}")
#
# File ~\miniconda3\Lib\site-packages\geemap\common.py:121, in ee_export_image(ee_object, filename, scale, crs, crs_transform, region, dimensions, file_per_band, format, unzip, unmask_value, timeout, proxies)
#     118 # Need to initialize r to something because of how we currently handle errors
#     119 # We should aim to refactor the code such that only one try block is needed
#     120 r = None
# --> 121 r = requests.get(url, stream=True, timeout=timeout, proxies=proxies)
#     123 if r.status_code != 200:
#     124     print("An error occurred while downloading.")
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\miniconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\miniconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\miniconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\miniconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Export monthly QC masks

# %%
def export_qc_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2=3000):
    os.makedirs(local_output_folder, exist_ok=True)
    asset_list = ee.data.listAssets({'parent': asset_root_path})['assets']

    for asset in asset_list:
        asset_id = asset['name']
        basename = asset_id.split('/')[-1]  # QC_YYYY_MM
        match = re.match(r'QC_(\d{4})_(\d{2})', basename)
        if not match:
            continue
        year = int(match.group(1))
        if not (start_year <= year <= end_year):
            continue

        print(f"🧪 Processing {basename}")
        image = ee.Image(asset_id).select('expansion_mask').unmask(-1).int8()
        region = image.geometry()
        output_path = os.path.join(local_output_folder, f"{basename}.tif")

        try:
            geemap.ee_export_image(
                image,
                filename=output_path,
                scale=30,
                region=region.getInfo()['coordinates'],
                file_per_band=False,
                crs='EPSG:4326'
            )
        except Exception as e:
            print(f"⚠️ Failed full export for {basename}: {e}")

        if not os.path.exists(output_path):
            print(f"🔁 Falling back to tiling for {basename}")
            tiles = tile_geometry(region, tile_size_km2)
            for i, tile in enumerate(tiles):
                tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
                try:
                    geemap.ee_export_image(
                        image.clip(tile),
                        filename=tile_path,
                        scale=30,
                        region=tile.getInfo()['coordinates'],
                        file_per_band=False,
                        crs='EPSG:4326'
                    )
                except Exception as te:
                    print(f"❌ Tile {i} failed: {te}")
            stitch_tiles(local_output_folder, basename, shapefile_path)
        else:
            print(f"✅ Successfully exported {basename} (no tiling needed)")
            clip_raster_to_shape(output_path, shapefile_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
export_qc_assets_tiled(
    asset_root_path='projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/QC_Masks',
    local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
    shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
    start_year=1991,
    end_year=1991,
    tile_size_km2=10000  # You can reduce this if you see export failures
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 🧪 Processing QC_1991_01
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for QC_1991_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/06d44d238911b41b63c8dcfeb8155233-385403dd60b9e28396b0a3ca9decaa28:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0d85a7ba6ca9b1e977f621e1e9fe3580-36d7e0667a399d6ec9c8fa5486586b6c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f302576622c1b3ef3a7eb2aa824dab2a-8cae5f6ad0855ee2a14fce620c063155:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/467f1fe756014974a55afdb2470b2b9a-5b77b5f772128757362d5ccac9af5209:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ea5c814b5da52d56c9cd7cccf678be51-625134359f269ce0724e31d01983c91c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0c73d64d876c3cfb99448aaab2599b78-73f7c5a288b5d24f4ca6efe4e9da8603:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/3595a267dffee4a0e91744747e6ed49c-2da62b49021cff9fb7962f384a50a88c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/5e15aba22d8a265889e663cacac1b811-3c06632561ef7e7c8f723ab6d9bf87fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/638d1236ec04901a9773c984b5492ba5-29ae5680f5b4f3bf664d8e8411cc071b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01_tile_8.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_01.tif
# 🧪 Processing QC_1991_02
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for QC_1991_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f97b172f278f11403d1881922b1ec52c-cfeecaa133c8a72008f5b3bfae4187b0:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c0484d61035e4011b5ff4d64a4849ce4-e934575ba948c6c2ca4b9e5cc09a33b3:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/57273d7157672bab24a32f6b33251320-d51747b2b6e57bc7a967fb95edad8acb:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f7c78d21d71a814c5481f775633971ba-e9f52edc1fb766d4fae818a898e1818a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/daec9bb5ca20097d008a351fa4b10b7c-f20e87ec851292101e1cb76a65a43ea8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/1a527c80f81f988677bcd54472851f4b-5f64968cebbb351b782a2e8b1bf1f0d7:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/38ad466691a04a044fd6c67e825d4aeb-b91afb1a964987b71b1b1bc9f537bb9d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/63f7d91d9d6fc94ab696eb4ca5edc993-c0e5625bc47bd22f7a69cd2644d16642:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/8d3dbe5f74cc39e556a560fca15496b2-4803669097be88af233ab22d18d9cbed:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02_tile_8.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_02.tif
# 🧪 Processing QC_1991_03
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for QC_1991_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/da152c5812a59df0d45df347eea00e7b-37af8b5f8b6efb7f5979672fb7cf346a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/abf297ce9bce658b6b89678a2035e114-5ab0155ee7fb71c561ca3a05b94f2c51:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/136677b576537586e725558e120e543c-74bdad9518e82515b579dc447290de39:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/81ef84f34c78f2bf60fd4e85fd97cf1a-aac1d4184cf414bb43e9874efed1e3c8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/7382f88879493613d5fa1cba826f030e-ccab21ac52686cbee672eb5a09198e06:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/4444ab0ad8aae7f5efa5946087bd8d29-65bbd34bffd289ae9758cda49280183b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/fd7b12494665ae211689248fbbba3910-d587f726a96d10f29e5967b15f03351c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/46baf5d7a2e7736168d1df2f8c0a845f-ba631bb16226efe36e384bc9e8b5b529:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ec79b1d482c8e7f834bf7a0cc053a3f9-9345452bd3fd49d0a6410339a04855bf:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03_tile_8.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_03.tif
# 🧪 Processing QC_1991_04
# Generating URL ...
# An error occurred while downloading.
# Total request size (118405416 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for QC_1991_04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/b4db3a925ce9591d74f919c838d02889-f223130f0bffa7099c7e0d2ba2c3a7e8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_04_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/109bbf7790c4158d3a88b71e80b6f13a-e96ad3d6e10458eb72d0d0cb6d1e22d9:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_04_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/42d96252585208d4e97e1592394f997e-be04af7fc14af17bafc4e786abef575f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_04_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/58fdbc96ddf921f1d3519991ac3713e5-3dad4f34607912b14329a992244625a5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_04_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/648d3e71a65cf28c82c657aba0e38f46-0064cbb21481704979bb864fa42a84f5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\QC_1991_04_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/159182190db577718c04925935aedb73-108e159e644be5dd99cad7da23dbe522:getPixels
# Please wait ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 export_qc_assets_tiled(
#       2     asset_root_path='projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/QC_Masks',
#       3     local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
#       4     shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
#       5     start_year=1991,
#       6     end_year=1991,
#       7     tile_size_km2=10000  # You can reduce this if you see export failures
#       8 )
#
# Cell In[22], line 38, in export_qc_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2)
#      36 tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
#      37 try:
# ---> 38     geemap.ee_export_image(
#      39         image.clip(tile),
#      40         filename=tile_path,
#      41         scale=30,
#      42         region=tile.getInfo()['coordinates'],
#      43         file_per_band=False,
#      44         crs='EPSG:4326'
#      45     )
#      46 except Exception as te:
#      47     print(f"❌ Tile {i} failed: {te}")
#
# File ~\miniconda3\Lib\site-packages\geemap\common.py:121, in ee_export_image(ee_object, filename, scale, crs, crs_transform, region, dimensions, file_per_band, format, unzip, unmask_value, timeout, proxies)
#     118 # Need to initialize r to something because of how we currently handle errors
#     119 # We should aim to refactor the code such that only one try block is needed
#     120 r = None
# --> 121 r = requests.get(url, stream=True, timeout=timeout, proxies=proxies)
#     123 if r.status_code != 200:
#     124     print("An error occurred while downloading.")
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\miniconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\miniconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\miniconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\miniconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Export monthly Landsat RGB composites

# %%
def export_rgb_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2=3000):
    os.makedirs(local_output_folder, exist_ok=True)
    asset_list = ee.data.listAssets({'parent': asset_root_path})['assets']

    for asset in asset_list:
        asset_id = asset['name']
        basename = asset_id.split('/')[-1]
        match = re.match(r'Composite_(\d{4})_(\d{2})', basename)
        if not match:
            continue
        year = int(match.group(1))
        if not (start_year <= year <= end_year):
            continue

        print(f"🎨 Processing {basename}")
        image = ee.Image(asset_id).select(['Red', 'Green', 'Blue'])  # Order: RGB
        region = image.geometry()
        output_path = os.path.join(local_output_folder, f"{basename}.tif")

        # Apply scaling to preserve float precision (optional)
        image = image.multiply(10000).toUint16()

        try:
            geemap.ee_export_image(
                image,
                filename=output_path,
                scale=30,
                region=region.getInfo()['coordinates'],
                file_per_band=False,
                crs='EPSG:4326'
            )
        except Exception as e:
            print(f"⚠️ Failed full export for {basename}: {e}")

        if not os.path.exists(output_path):
            print(f"🔁 Falling back to tiling for {basename}")
            tiles = tile_geometry(region, tile_size_km2)
            for i, tile in enumerate(tiles):
                tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
                try:
                    geemap.ee_export_image(
                        image.clip(tile),
                        filename=tile_path,
                        scale=30,
                        region=tile.getInfo()['coordinates'],
                        file_per_band=False,
                        crs='EPSG:4326'
                    )
                except Exception as te:
                    print(f"❌ Tile {i} failed: {te}")
            stitch_tiles_rgb(local_output_folder, basename, shapefile_path)
        else:
            print(f"✅ Successfully exported {basename} (no tiling needed)")
            clip_raster_to_shape(output_path, shapefile_path)

def stitch_tiles_rgb(output_folder, basename, shapefile_path):
    tile_paths = glob.glob(os.path.join(output_folder, f"{basename}_tile_*.tif"))
    if not tile_paths:
        print("No tiles found to stitch.")
        return
    if len(tile_paths) == 1:
        os.rename(tile_paths[0], os.path.join(output_folder, f"{basename}.tif"))
    else:
        srcs = [rasterio.open(p) for p in tile_paths]
        mosaic, transform = merge(srcs)
        for src in srcs:
            src.close()

        meta = srcs[0].meta.copy()
        meta.update({
            "height": mosaic.shape[1],
            "width": mosaic.shape[2],
            "transform": transform,
            "compress": "LZW",
            "nodata": 0,
            "dtype": "uint16",
            "count": 3  # RGB bands
        })

        out_path = os.path.join(output_folder, f"{basename}.tif")
        with rasterio.open(out_path, "w", **meta) as dest:
            dest.write(mosaic)

        for path in tile_paths:
            os.remove(path)

    clip_raster_to_shape(os.path.join(output_folder, f"{basename}.tif"), shapefile_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
export_rgb_assets_tiled(
    asset_root_path="projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/Source_LS_Composites",
    local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
    shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
    start_year=2023,
    end_year=2023,
    tile_size_km2=5000
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 🎨 Processing Composite_2023_01
# Generating URL ...
# An error occurred while downloading.
# Total request size (532824372 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for Composite_2023_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6c9cd7a98ebc26e8f6d9c5b1480df5f9-f78ccd531d7ef709230e5a6246df03fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/8309827b8d94c53f5b366a45352068d7-f8fd440132c983c46d01e85893b31e37:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6e1602f20badbd0efecb23ba256577c7-a676ad3b03f97e4e6d99bef7377c616e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/923b0ca8b2f6020373d948531e9ef79f-cae4915f05a7c87f6adc5a54ad847652:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a2a487359917fcaa1d9453ebd27b2a5c-0ae4047c520006d866188d98b136862d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/61eed2a0d0f024ee0face37d9bdfe2c4-908e3227758a1b748044064d37fc4fcb:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0374979a6412598dd057176baa81f673-67510eb182941b468d0c068d9f288696:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9b998101ed0770633dc862235768250e-ec6369e7b8449bd8f2ddfedccf54e422:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c90f4d4134fd490317911091bd42f3e1-456e07065324616cfb5b16494f71618e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/045503377f32334c41a7eb2772261e71-40bf9a1d17843970d5a5c540c6204834:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a377d475469a2aba946341816dc4aca1-83c6ad1776db6a81a2b8187a418e9d7e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9ea0b6474c59cc14158dd1be9008f85c-472bdb6c095d1890f4dad4684330d924:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/600d419849a377aa57591049fa6c5474-0c62820b3683367badda5c8b88cc0678:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e9562504c3a89091f7c2aadfc716f811-803692848a949cf12a7060c028e818ef:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ca4aad2bb7011e8c55c6f4f0bbf64a0c-cf1a4f853fa81b2b8d1e9a84e58b9eef:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/464ff790303f63818626ea50ecc7f5e4-01075487f5ead641dacf1ad9319d05a1:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01_tile_15.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_01.tif
# 🎨 Processing Composite_2023_02
# Generating URL ...
# An error occurred while downloading.
# Total request size (532824372 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for Composite_2023_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e1baf07ffe6f27c2a6d5b0d65d177f3b-0ee39d74fbc3d6984549b67ab0ba7006:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d6c034b608dd8f3c4fe4ada3d7529914-933347992320e0920d3dbfd05f63b7da:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/aeed7436d7f7f1e4ce17a73b6fbc2d00-4fb680ad371399d41711002c70f5d39c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/aadf21ae7b7fdbcb8716e553e5425bd1-bab960310f00d3d80fa3030342686b4f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a12d4fc746c477064b9d689df534aba8-72624e061c1c64768726fd87f51e38c8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/048a0b0a6a103fe998dc23d78d4281f2-bd2a8254fd4e1376cc1900957315709c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/52f93bf695d5b14961b9dd29d61577b7-6eeac1b5a00267285e85a50f27cea0af:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/4ae6c5460bc61ea692a3d54ec09c66d8-1e23499fda18b196d57c77340d3cebf7:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/fb7651a46fb531a3ca0eec94a2e92277-b6bf0bb752892b3c690b41e28df2d158:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9366157a90b435da078c36853cfca421-831a3cd6eaa6141b5ae67d81df2f0e32:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/bd202aa2e753dd11ecbfce09c941230b-5607177f4873fe6206cf952461bfa247:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/4bf6892e6a6516a60906c8fd317d05fb-f6bc612d791a1c59d16784ee9ed38d92:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d7337dcdfc323b15d011307986bc17e8-fd3145aae85f613190b5eb9755532530:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/da25b3a24cd3994393cc5f62ed59dcb6-555144b2522fad2c060ad31fd5a5e04a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/14428be5bb2909b3cff64cb785f70167-f9ef5a789caeb8763c0d7cb08fe913d6:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d012c54a2a45e4b593f8f4ab41c5c509-ff4a2248e5c3c6a22438b39f28a830db:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02_tile_15.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_02.tif
# 🎨 Processing Composite_2023_03
# Generating URL ...
# An error occurred while downloading.
# Total request size (532824372 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for Composite_2023_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e16ba9d1bd91ab09bec9063e3dd7f79c-9270c8330a79d7153da93f19641355bd:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/5b038c2379ec1d8fab15edb97bae9818-3e48fd633b3cf6677e05acc9350ebea6:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/482201a1561c5681a90a759b88cb8443-10ccabbab8ed44f09a18665465423c5b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e418e03175e4fd84cad1c1bc3d0cdfa1-406eade1cd6e9ff58a795f41915aa6ce:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c8cf5289bd5b34b857164574f6e6ea96-cfd4b7646503d903fff4830840b182e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c6584f772f7869fbe1f75c146205fbc9-27f60e8bd297c7a6ff825a3007d2c275:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/98e9a4621152e993c3bcf622c4cf47d3-970df7e03a08489b9b2fa94e77dd5841:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0dc0211b1f27b7eb0f00da0526eaa3f9-338b7b2778b6ab67e507781983309f8b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d481e7a5376c8be7a56cdcf2e65a2d67-4dd2a0fbc8851b3e439b5bce682fe54e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9bca257da83daafa8f31357d8508d291-853e33556aa6a3e60eb74849b840e57a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/00cb1c4ea6a9421d3ae0f7808524cd3d-4ad33f17afa2954a166477a183f084bd:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a68771531d9fd79b35c75651fba26953-230a39eb45d09e3c9bdd3e527f8b830e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f3514d4e5a98cc33aaa96ebaf2408c3b-4764746e00d29b3124bd9a2aeb18b4a5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6ff8745b71f294434f874abb6c6bf874-0a6214e426197cb6a8b1826b86389115:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/dadd5dcb4dbcae8459b5e6fb5eeb5147-36ccdc3933174d2c18f6d503b06f9268:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/b9c027575ec205ff84efdc4a99133dd0-5f364cc33605fdfd92cbd435b0b3e580:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03_tile_15.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_03.tif
# 🎨 Processing Composite_2023_04
# Generating URL ...
# An error occurred while downloading.
# Total request size (532824372 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for Composite_2023_04
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a342834242e21356e09aa25268897e7f-b6e88f7125c9e4c73bfb135b5730c7f3:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/69e618951a25e250625da16e8d373552-ff9d080fb1a191bde75b5c9d12a7a2fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/bc50070a7cf5c6d1250913996b4f32ea-1f8a45658d597585fc1ed4cb765a4049:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0222c270d5431c1eea97546a248f5ea3-a50dea7f46092dfee9680ea39a3defb1:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/5ae325420e8641b2cb33c15159e41ed4-6d927f325327626acf6774733384546b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/112894dd85fa1c7642c6bdbfa1561980-05e7fecf3f83e1cad0095912e158e1ed:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/de619b7297ab686d2d7d6bcabb316d5f-2d94bd83f962b8162b3d0d45de8f8906:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e946ce38c854b8837c804e9a4cfec90f-bd7ff880055b29401ffb4e532e306957:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/3ca464575d1938ec44d13ddc5d3f468e-3077f904285bcb16e292720f8c76e6c0:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/cf126dceb39d10e3d6073e07253bb296-1a6ca19f2dca75f2a752d86844a64a19:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\Composite_2023_04_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/44e961ae716fb4f9a04b4680e85659a5-2816904ae6bb95110c305570e7abb093:getPixels
# Please wait ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 export_rgb_assets_tiled(
#       2     asset_root_path="projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v2/Source_LS_Composites",
#       3     local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
#       4     shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
#       5     start_year=2023,
#       6     end_year=2023,
#       7     tile_size_km2=5000
#       8 )
#
# Cell In[10], line 41, in export_rgb_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2)
#      39 tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
#      40 try:
# ---> 41     geemap.ee_export_image(
#      42         image.clip(tile),
#      43         filename=tile_path,
#      44         scale=30,
#      45         region=tile.getInfo()['coordinates'],
#      46         file_per_band=False,
#      47         crs='EPSG:4326'
#      48     )
#      49 except Exception as te:
#      50     print(f"❌ Tile {i} failed: {te}")
#
# File ~\miniconda3\Lib\site-packages\geemap\common.py:121, in ee_export_image(ee_object, filename, scale, crs, crs_transform, region, dimensions, file_per_band, format, unzip, unmask_value, timeout, proxies)
#     118 # Need to initialize r to something because of how we currently handle errors
#     119 # We should aim to refactor the code such that only one try block is needed
#     120 r = None
# --> 121 r = requests.get(url, stream=True, timeout=timeout, proxies=proxies)
#     123 if r.status_code != 200:
#     124     print("An error occurred while downloading.")
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\miniconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\miniconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\miniconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\miniconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Export Sentinel-2 based DSWE products

# %%
def export_dswe_s2_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2=1000):
    os.makedirs(local_output_folder, exist_ok=True)
    asset_list = ee.data.listAssets({'parent': asset_root_path})['assets']

    for asset in asset_list:
        asset_id = asset['name']
        basename = asset_id.split('/')[-1]  # DSWE_YYYY_MM
        match = re.match(r'DSWE_(\d{4})_(\d{2})', basename)
        if not match:
            continue
        year = int(match.group(1))
        if not (start_year <= year <= end_year):
            continue

        print(f"🛰️ Processing {basename}")
        image = ee.Image(asset_id).select('DSWE').unmask(-1).int8()
        region = image.geometry()
        output_path = os.path.join(local_output_folder, f"{basename}.tif")

        try:
            geemap.ee_export_image(
                image,
                filename=output_path,
                scale=10,
                region=region.getInfo()['coordinates'],
                file_per_band=False,
                crs='EPSG:4326'
            )
        except Exception as e:
            print(f"⚠️ Failed full export for {basename}: {e}")

        if not os.path.exists(output_path):
            print(f"🔁 Falling back to tiling for {basename}")
            tiles = tile_geometry(region, tile_size_km2)
            for i, tile in enumerate(tiles):
                tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
                try:
                    geemap.ee_export_image(
                        image.clip(tile),
                        filename=tile_path,
                        scale=10,
                        region=tile.getInfo()['coordinates'],
                        file_per_band=False,
                        crs='EPSG:4326'
                    )
                except Exception as te:
                    print(f"❌ Tile {i} failed: {te}")
            stitch_tiles(local_output_folder, basename, shapefile_path)
        else:
            print(f"✅ Successfully exported {basename} (no tiling needed)")
            clip_raster_to_shape(output_path, shapefile_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
export_dswe_s2_assets_tiled(
    asset_root_path='projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m',
    local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
    shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
    start_year=2023,
    end_year=2023,
    tile_size_km2=3000
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 🛰️ Processing DSWE_2023_01
# Generating URL ...
# An error occurred while downloading.
# Total request size (1065143040 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/05d8d525f41a7e87c91cb83e25a441eb-2890073ac09f057dd5419bdae5381538:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/85ccb798e0ea5df74fb4fd1af5118810-444b6ddf89ee65f3a5dd80942682cec5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/1e82131760c8e6c05b22f71f7c16e2bf-ef25389e7f66fe0fa5f6e0fe6ca8f383:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/35acd7ecaa6f40718f80215f2b29523e-7234028f0493ff05cb86f90c7d99b049:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/67dd51833840c21af3b6e6f82f05cc45-811cb4fefd035ae5176ee3735084eb4d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a815d75b79823d5da046a8c546ec8212-0782336e4ebd114ae52554cff3b66b16:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c2bd1c89211e342dcf7c7f4b51af0261-5a1ab58f41a944eb5c9d9f73fcd0638b:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9eafd5259a6173e3f3e1244dd32c28a4-449309ee1798306c2d048712efd5ac83:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/dd5fecdedeee214eb74b03b985fdae45-9e743c3f8a08f3533ef6a4fe674bc483:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/bddb5d7f1be030dd5fa5bf1fdfa2eda0-ea3e3bf00bc83b3a1d44ec1eda6bc5b3:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/02acd1dcfbff6484e0466969e37ddb72-da599849bf0db97fbd84c19079c07f9f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c890bfb454b6620a0123b2ffee75126f-afd34e0b3abd056c7e16b2606f709ab9:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e2047bc9c8f65f76bbaf28f9654f8339-0dd9dda3b56a8c6ecc611b995e4e4740:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a2a3cf20d06500204f81c53c2f235c3b-7eab2906b019aed3a26669d9fd525150:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/3f23f42478b1f86515adeeaa9de28c64-69d884e850c7ef7af0c4f89621441d29:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f50b9f1654eb1a49935af00994d0c99b-397738e701d116fd6bc6065a49119af5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/2bca226448c9b0cfc34912b651b2ed38-d94f4bb4c030806b1b21abdfb9ee2c5a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f0c5e8f6966bca832da7d7bef3cff513-d9f4f001cce044cce1fc5d39d129fc5d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9380a67514fd34e5d9fce87d1cd87dec-c68745e1aafa6ee32fb8f03351b539a6:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0ec4a04d01e28cfd75bcb5a4948588b3-e9880d5307716d14bfe9f34929e3080d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/5218ddf59fed07a44fe8e9700aec21ff-45ea0ee114ba9d31635286b4723d5601:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/607410d23032f225fab3b5892a6d2805-2640ca097ab94d4c2397cdf17e5267a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/fd2381519cda8f3d487bfcf2ac208d26-21c7a2f984c0e1be3e6c8f57f5c92bd8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/840e502981ee2f661e2ca89a09d097cb-028de08f6d0c9bfe25998fed36d3d116:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e8e5de806ba832f42882139ed999b40d-477fe48d5cc99b4612f06f3017e402e1:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01_tile_24.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_01.tif
# 🛰️ Processing DSWE_2023_02
# Generating URL ...
# An error occurred while downloading.
# Total request size (1065143040 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_02
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/3c301103e81bc19beb2617ce655fddbf-e315c6c004f17f0ca51ec77e816d9c5c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/e5157cd681a530e25920264e4722c045-d6cd40970c109fc834d71af81ca1a25d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ee9fe732511cb7f3f1c93b29ba197361-d6e5d820c8c6f0ac35729b2ca353269d:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c8eaa61a5c8e8201bc56e443e7b00ba8-4adbac4510a6aaec3fea2ae22c89f800:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/0a992a8a1010d307ba14537eb11ad877-f791888fb30cb56770ad4434c49aef49:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/f0775a64b377d117abecb86481a330ca-ff0dcba4e4b0f6a447d934d033fb48e4:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/8e6f7029a4e570f376add760a393143a-a9a0c613a23c7b22b184b0b4cdb33cfa:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6f2f8f0ab74d10459aa0c4b61c9052ef-4a2acdc63dba664a1baa41a3b7cfd5ca:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/40c0524cb115e80b8ca14ef42a09fad4-033ed73c5c11434939b4b12970b35996:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/d4a6d681753206509367128b98cf0780-9bd7c9bacdaf6dbdce1c98878d25fa40:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/77068a4e2164c06dcaa1c8f7ea4478bc-96597d9d851d417dcecd6825e7fe15fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/210f9089020f19b16244a45d5c900146-f1f7570109f102a91d76ffe0cd9fe25e:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/da9b0f912cdf1c77fb88bf9e1ff80213-82c84f036869b295ebbf8af98a2224e1:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/9135074850eedbfe0ef45635d9b03a8c-b618bfda43d43e7d0255a7c8fe6fbc7f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/ed7666450613771b5cec2146ebfa8346-7856c12ab4d403d0384431b1b9e000c0:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_14.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/27025d49f0f3cf29b18c0935fe1287ef-4fa90dbcc8be0b94c4fb660cace5497c:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/36bfa094945f6f62c9bb7cc611558dc6-96e174d63113d4fb7a5fed32385dd513:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/2c33575707c531d92986a1e12d26494a-d18c90ab0e1316ec0505ece28ca3b91a:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/de5a6bba41ce836a0750f22e60779f96-fab9b9b15c97f5a0115a4053ade8c3fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/08e39ca616ebb46861142ccc7e998665-3a4a8d4c15257f4663214a81193281df:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/28ef717297042c0cd21d5ef85b372e25-e3fc5ac59af94e34d8fb3dce0942a456:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/c308a6686f63ecbbf84273b71ba21e0c-36816dde69489d07129b34ff399f54a2:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a140abe12c9c91de07209576296a4400-f1ac1c88f215671c3b45308433c560a9:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/11c29e8309354a54fdb2a224ffaf9592-4048e947ed6404cd72b2648fe16e1d86:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/4ce67a3c7f24ba239bba8c8b64cb811f-e6c76f330866a9ca49a796a6c58e90e3:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02_tile_24.tif
# ✅ Clipped raster saved (overwritten): C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_02.tif
# 🛰️ Processing DSWE_2023_03
# Generating URL ...
# An error occurred while downloading.
# Total request size (1065143040 bytes) must be less than or equal to 50331648 bytes.
# 🔁 Falling back to tiling for DSWE_2023_03
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/1aa51a081680c0c3aca3ddd4f461d722-c2c0af07f9939baeac560dbf87983b31:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/49358c3b983460e138e80a6d2aec4cd0-bebe1d409336291fe78264f5af9aea0f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/90d5d97fdcf98d42502e87bde55628e7-e400edcdb62e10542b60a5c6834f639f:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/df05bf406daab17e3320931ec9e9dca4-1a37002255cb3e5a3d6619973668eee5:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/25469ba3a8a6933aec9a986e1cc5b0f9-83776d53bc0c9d7fec014dc230226878:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a1323ea8c660296926c4c5fa5d71d99b-4641991b91212d4a90104ff08b1824a8:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/89a7563944821c2819378aa61e7e3404-d57a43b708a366181bd57fa0aac56193:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/a1333f7ff70b645d42a3821d5d733af4-0c1d747ddc234079f26df86c0b185282:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/6b9929f8dc0a71f7013bb15edecf91e9-5227d7348097ac508cbe8c694cde6612:getPixels
# Please wait ...
# Data downloaded to C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting\DSWE_2023_03_tile_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/153793833549/thumbnails/cd1b76859f4e8ea7205288bd903d5ce9-914cb60f35e2abfd013f9c8879342c2a:getPixels
# Please wait ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 export_dswe_s2_assets_tiled(
#       2     asset_root_path='projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m',
#       3     local_output_folder=r'C:\Users\huckr\Desktop\UCSB\Okavango\Data\Code\Troubleshooting',
#       4     shapefile_path=r"C:\Users\huckr\Desktop\UCSB\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp",
#       5     start_year=2023,
#       6     end_year=2023,
#       7     tile_size_km2=3000
#       8 )
#
# Cell In[26], line 38, in export_dswe_s2_assets_tiled(asset_root_path, local_output_folder, shapefile_path, start_year, end_year, tile_size_km2)
#      36 tile_path = os.path.join(local_output_folder, f"{basename}_tile_{i}.tif")
#      37 try:
# ---> 38     geemap.ee_export_image(
#      39         image.clip(tile),
#      40         filename=tile_path,
#      41         scale=10,
#      42         region=tile.getInfo()['coordinates'],
#      43         file_per_band=False,
#      44         crs='EPSG:4326'
#      45     )
#      46 except Exception as te:
#      47     print(f"❌ Tile {i} failed: {te}")
#
# File ~\miniconda3\Lib\site-packages\geemap\common.py:121, in ee_export_image(ee_object, filename, scale, crs, crs_transform, region, dimensions, file_per_band, format, unzip, unmask_value, timeout, proxies)
#     118 # Need to initialize r to something because of how we currently handle errors
#     119 # We should aim to refactor the code such that only one try block is needed
#     120 r = None
# --> 121 r = requests.get(url, stream=True, timeout=timeout, proxies=proxies)
#     123 if r.status_code != 200:
#     124     print("An error occurred while downloading.")
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\miniconda3\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\miniconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\miniconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\miniconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\miniconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
