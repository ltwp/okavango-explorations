# %% [markdown]
# # Monthly Landsat DSWE Generator
#
# This code employs Landsat 5, 7, 8, and 9 remote sensing data within the Dynamic Surface Water Extent (DSWE) algorithm to develop monthly water inundation extent maps and supplemental gridded products (QC raster and RGB of source composite) for a given study area. The code first creates monthly composites from avaialable Landsat data, then applies the algorithm. If the total study area has <95% coverage (accounting for cloud and cloud shadowed pixels), the non-classified areas are classified using a composite of Landsat imagery from +- 1 month. If the coverage is still < 95%, the remaining unclassifed area is classified using a range of +- 2 months and so on. The maximum expansion range default is +- 3 months, but may be edited. The resulting exports (GEE assets) include the DSWE product, the RGB bands of the source composite, and a QC product showing the total expansion range needed to classify each pixel, with 0 being the highest quality and 3 being the lowest.
#
# DSWE Methodology: Jones, J.W., 2019. Improved Automated Detection of Subpixel-Scale Inundation—Revised Dynamic Surface Water Extent (DSWE) Partial Surface Water Tests. Remote Sensing 11, 374. https://doi.org/10.3390/rs11040374
#
# Landsat Collection 2: Earth Resources Observation and Science (EROS) Center. (2020). Landsat 8-9 Operational Land Imager / Thermal Infrared Sensor Level-2, Collection 2 [dataset]. U.S. Geological Survey. https://doi.org/10.5066/P9OGBGM6. Earth Resources Observation and Science (EROS) Center. (2020). Landsat 7 Enhanced Thematic Mapper Plus Level-2, Collection 2 [dataset]. U.S. Geological Survey. https://doi.org/10.5066/P9C7I13B. Earth Resources Observation and Science (EROS) Center. (2020). Landsat 4-5 Thematic Mapper Level-2, Collection 2 [dataset]. U.S. Geological Survey. https://doi.org/10.5066/P9IAXOVV.
#
# Google Earth Engine: Gorelick, N., Hancher, M., Dixon, M., Ilyushchenko, S., Thau, D., Moore, R., 2017. Google Earth Engine: Planetary-scale geospatial analysis for everyone. Remote Sensing of Environment, Big Remotely Sensed Data: tools, applications and experiences 202, 18–27. https://doi.org/10.1016/j.rse.2017.06.031
#
# Code adapted from Dr. Evan Greenberg: https://github.com/evan-greenbrg Greenberg, E., Chadwick, A.J., Ganti, V., 2023. A Generalized Area-Based Framework to Quantify River Mobility From Remotely Sensed Imagery. Journal of Geophysical Research: Earth Surface 128, e2023JF007189. https://doi.org/10.1029/2023JF007189
#
# Author: James (Huck) Rees, PhD Student, UC Santa Barbara Geography
#
# Date: August 18, 2025

# %% [markdown]
# ## Import packages

# %%
import ee
import geopandas as gpd
import os
import logging
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import calendar

ee.Initialize()

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ## Initialize functions

# %%
# Normalized Difference Water Index (MNDWI)
def Mndwi(image):
    """
    Calculate the Modified Normalized Difference Water Index (MNDWI) for a given image.

    Parameters:
    image (ee.Image): The input image.

    Returns:
    ee.Image: The resulting image with the MNDWI band named 'mndwi'.
    """
    return image.normalizedDifference(['Green', 'Swir1']).rename('mndwi')

# Modified Bare Soil Reflectance Variables
def Mbsrv(image):
    """
    Calculate the Modified Bare Soil Reflectance Variable (MBSRV) for a given image.

    Parameters:
    image (ee.Image): The input image.

    Returns:
    ee.Image: The resulting image with the MBSRV band named 'mbsrv'.
    """
    return image.select(['Green']).add(image.select(['Red'])).rename('mbsrv')

def Mbsrn(image):
    """
    Calculate the Modified Bare Soil Reflectance Normalized (MBSRN) for a given image.

    Parameters:
    image (ee.Image): The input image.

    Returns:
    ee.Image: The resulting image with the MBSRN band named 'mbsrn'.
    """
    return image.select(['Nir']).add(image.select(['Swir1'])).rename('mbsrn')

# Normalized Difference Vegetation Index (NDVI)
def Ndvi(image):
    """
    Calculate the Normalized Difference Vegetation Index (NDVI) for a given image.

    Parameters:
    image (ee.Image): The input image.

    Returns:
    ee.Image: The resulting image with the NDVI band named 'ndvi'.
    """
    return image.normalizedDifference(['Nir', 'Red']).rename('ndvi')

# Automated Water Extraction Index (AWESH)
def Awesh(image):
    """
    Calculate the Automated Water Extraction Index (AWEsh) for a given image.

    Parameters:
    image (ee.Image): The input image with the necessary bands for MBSRN calculation.

    Returns:
    ee.Image: The resulting image with the AWEsh band named 'awesh'.
    """
    return image.expression(
        'Blue + 2.5 * Green + (-1.5) * mbsrn + (-0.25) * Swir2',
        {
            'Blue': image.select(['Blue']),
            'Green': image.select(['Green']),
            'mbsrn': Mbsrn(image).select(['mbsrn']),
            'Swir2': image.select(['Swir2'])
        }
    ).rename('awesh')

# Decision Tree for Surface Water Extent (DSWE)
def Dswe(image):
    """
    Calculate the Decision Tree for Surface Water Extent (DSWE) for a given image.

    Parameters:
    image (ee.Image): The input image with bands required for the DSWE calculation.

    Returns:
    ee.Image: The resulting image with the DSWE classification named 'dswe'.
    """
    mndwi = Mndwi(image)
    mbsrv = Mbsrv(image)
    mbsrn = Mbsrn(image)
    awesh = Awesh(image)
    swir1 = image.select(['Swir1'])
    nir = image.select(['Nir'])
    ndvi = Ndvi(image)
    blue = image.select(['Blue'])
    swir2 = image.select(['Swir2'])

    # Decision tree thresholds
    t1 = mndwi.gt(0.124)
    t2 = mbsrv.gt(mbsrn)
    t3 = awesh.gt(0)
    t4 = (mndwi.gt(-0.44)
          .And(swir1.lt(0.09))
          .And(nir.lt(0.15))
          .And(ndvi.lt(0.7)))
    t5 = (mndwi.gt(-0.5)
          .And(blue.lt(0.1))
          .And(swir1.lt(0.3))
          .And(swir2.lt(0.1))
          .And(nir.lt(0.25)))

    # Combine results using weights to create unique classes
    t = t1.add(t2.multiply(10)).add(t3.multiply(100)).add(t4.multiply(1000)).add(t5.multiply(10000))

    # Define DSWE classification levels
    noWater = t.eq(0).Or(t.eq(1)).Or(t.eq(10)).Or(t.eq(100)).Or(t.eq(1000))
    hWater = t.eq(1111).Or(t.eq(10111)).Or(t.eq(11011)).Or(t.eq(11101)).Or(t.eq(11110)).Or(t.eq(11111))
    mWater = (t.eq(111).Or(t.eq(1011)).Or(t.eq(1101)).Or(t.eq(1110))
              .Or(t.eq(10011)).Or(t.eq(10101)).Or(t.eq(10110))
              .Or(t.eq(11001)).Or(t.eq(11010)).Or(t.eq(11100)))
    pWetland = t.eq(11000)
    lWater = (t.eq(11).Or(t.eq(101)).Or(t.eq(110)).Or(t.eq(1001))
              .Or(t.eq(1010)).Or(t.eq(1100)).Or(t.eq(10000))
              .Or(t.eq(10001)).Or(t.eq(10010)).Or(t.eq(10100)))

    # Assign classification levels to DSWE
    iDswe = (noWater.multiply(0)
             .add(hWater.multiply(4))
             .add(mWater.multiply(3))
             .add(pWetland.multiply(2))
             .add(lWater.multiply(1)))

    return iDswe.rename(['dswe'])

def maskL8sr(image):
    """
    Masks out clouds and cloud shadows in Landsat 8/9 imagery using the BQA band.
    Uses bits 8–9 for cloud confidence and bits 10–11 for shadow confidence.

    Args:
        image: ee.Image, the input Landsat image.

    Returns:
        ee.Image: The masked image with cloud and shadow pixels removed.
    """
    qa = image.select('BQA')

    # Cloud confidence (bits 8–9): mask if medium or high
    cloud_conf = qa.rightShift(8).bitwiseAnd(3)
    cloud_ok = cloud_conf.lte(1)

    # Shadow confidence (bits 10–11): mask if medium or high
    shadow_conf = qa.rightShift(10).bitwiseAnd(3)
    shadow_ok = shadow_conf.lte(1)

    mask = cloud_ok.And(shadow_ok)
    return image.updateMask(mask)

def getLandsatCollection():
    """
    Merges Landsat 5, 7, 8, and 9 collections (Tier 1, Collection 2 SR) 
    and standardizes the band names for consistent analysis.

    Returns:
        ee.ImageCollection: A merged collection of standardized Landsat images.
    """
    # Define the band mappings for each Landsat version
    bn9 = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'QA_PIXEL']
    bn8 = ['SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B6', 'SR_B7', 'QA_PIXEL']
    bn7 = ['SR_B1', 'SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7', 'QA_PIXEL']
    bn5 = ['SR_B1', 'SR_B1', 'SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'SR_B7', 'QA_PIXEL']
    # Standardized names for all bands
    standard_bands = ['uBlue', 'Blue', 'Green', 'Red', 'Nir', 'Swir1', 'Swir2', 'BQA']

    # Fetch and rename bands in the Landsat collections
    ls5 = ee.ImageCollection("LANDSAT/LT05/C02/T1_L2").select(bn5, standard_bands)
    ls7 = ee.ImageCollection("LANDSAT/LE07/C02/T1_L2").filterDate('1999-04-15', '2003-05-30').select(bn7, standard_bands)
    ls8 = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2").select(bn8, standard_bands)
    ls9 = ee.ImageCollection("LANDSAT/LC09/C02/T1_L2").select(bn9, standard_bands)

    # Merge all collections
    merged_collection = ls5.merge(ls7).merge(ls8).merge(ls9)

    return merged_collection

def rescale(image):
    """
    Rescale the reflectance values of Landsat imagery to allow for use of Landsat Collection 2 in DSWE.

    Parameters:
    image (ee.Image): The input image with bands to be rescaled.

    Returns:
    ee.Image: The image with rescaled bands added.
    """
    bns = ['uBlue', 'Blue', 'Green', 'Red', 'Nir', 'Swir1', 'Swir2']
    optical_bands = image.select(bns).multiply(0.0000275).add(-0.2)
    return image.addBands(optical_bands, None, True)

def load_roi(shapefile_path):
    """Load ROI from a shapefile and return as an EE Geometry."""
    gdf = gpd.read_file(shapefile_path)
    return ee.Geometry.Polygon(gdf.unary_union.__geo_interface__["coordinates"])

# Function to generate a water mask for a given year and polygon feature
def get_water_mask_for_feature(start_date, end_date, max_level, polygon):
    """
    Generate a water mask for a given year and polygon feature using Landsat imagery.

    Parameters:
    year (int): The year for which to generate the water mask.
    max_level (float): The maximum DSWE water level threshold for classification.
    polygon (ee.Geometry.Polygon): The polygon feature defining the area of interest.

    Returns:
    ee.Image: The water mask image for the specified year and polygon.
    """
    imagery = (getLandsatCollection()
               .map(maskL8sr)
               .map(rescale)
               .filterDate(start_date, end_date)
               .filterBounds(polygon))

    image_composite = imagery.median().clip(polygon)
    water_mask = Dswe(image_composite)

    return water_mask

def export_to_asset(image, year, month, roi, asset_folder, bands=None, product_name="DSWE"):
    """
    Export a single-band or multi-band Earth Engine image to a GEE asset, 
    with proper metadata and asset ID formatting.
    
    Parameters:
        image (ee.Image): The image to export
        year (int): The image year
        month (int): The image month
        roi (ee.Geometry): Region of interest for clipping/export
        asset_folder (str): GEE asset folder path (no trailing slash)
        bands (list of str): Specific bands to export
        product_name (str): Prefix for the image asset name (e.g. "DSWE", "QC", "Composite")
    """
    asset_id = f"{asset_folder}/{product_name}_{year}_{month:02d}"
    
    # Select only specified bands if provided
    if bands:
        image_to_export = image.select(bands)
    else:
        image_to_export = image

    # Compute last day of month
    last_day = calendar.monthrange(year, month)[1]

    # Prepare image metadata
    image_with_metadata = image_to_export.set({
        'system:time_start': ee.Date(f"{year}-{month:02d}-01").millis(),
        'system:time_end': ee.Date(f"{year}-{month:02d}-{last_day:02d}").millis(),
        'source_ids': image.get('source_ids')
    })

    # Check if the asset already exists
    try:
        ee.data.getAsset(asset_id)
        logging.info(f"Skipping {asset_id}, already exists.")
    except:
        # Export the image with metadata
        task = ee.batch.Export.image.toAsset(
            image=image_with_metadata,
            description=f"{product_name}_{year}_{month:02d}",
            assetId=asset_id,
            scale=30,
            region=roi,
            maxPixels=1e13
        )
        task.start()
        logging.info(f"Exporting {asset_id}...")
        
def get_filled_composite_before_dswe(start_date, end_date, roi, max_months=6, fill_threshold=0.95):
    def get_composite(s, e):
        collection = (getLandsatCollection()
                      .map(maskL8sr)
                      .map(rescale)
                      .filterDate(s, e)
                      .filterBounds(roi))

        ids = collection.aggregate_array('system:index').distinct().sort()
        id_string = ids.join(",")  # Convert to comma-separated string
        return collection.median().clip(roi).set({'source_ids': id_string})

    def get_coverage(image):
        valid = image.select("Green").mask()
        stats = valid.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=roi,
            scale=30,
            maxPixels=1e13
        )
        return ee.Number(stats.get("Green"))

    base = get_composite(start_date, end_date)
    last_used_composite = base

    filled = base
    expansion_mask = base.select("Green").mask().Not().multiply(0).rename("expansion_mask")
    coverage = get_coverage(filled)

    for offset in range(1, max_months + 1):
        if coverage.gte(fill_threshold).getInfo():
            break

        delta = relativedelta(months=offset)
        expanded_start = (datetime.strptime(start_date, "%Y-%m-%d") - delta).strftime("%Y-%m-%d")
        expanded_end = (datetime.strptime(end_date, "%Y-%m-%d") + delta).strftime("%Y-%m-%d")
        extra = get_composite(expanded_start, expanded_end)
        last_used_composite = extra

        update_mask = base.select("Green").mask().Not()
        new_expansion = extra.select("Green").mask().And(update_mask).multiply(offset).rename("expansion_mask")
        expansion_mask = expansion_mask.where(expansion_mask.eq(0).And(new_expansion.neq(0)), new_expansion)

        filled = extra.blend(filled)
        coverage = get_coverage(filled)

    # Attach source scene metadata
    filled = filled.set({'source_ids': last_used_composite.get('source_ids')})
    return filled, expansion_mask

def process_monthly_dswe(start_date, end_date, shapefile_path, max_level, asset_folder,
                         export_dswe=True, export_qc=True, export_composite=True, export_swir2=True):
    """
    Generate and export DSWE composites for each month within the given date range,
    with optional export of DSWE, QC, RGB composite, and SWIR2 products, each to its own fixed subfolder.
    
    Parameters:
    -----------
    start_date : datetime
        Start date for processing
    end_date : datetime
        End date for processing
    shapefile_path : str
        Path to the ROI shapefile
    max_level : int
        Maximum DSWE level to include
    asset_folder : str
        Base folder path for asset exports
    export_dswe : bool, optional (default=True)
        Whether to export DSWE water classification products
    export_qc : bool, optional (default=True)
        Whether to export QC mask products
    export_composite : bool, optional (default=True)
        Whether to export RGB Landsat composite products
    export_swir2 : bool, optional (default=True)
        Whether to export SWIR2 band products
    """
    # Fixed subfolder names
    DSWE_FOLDER = "DSWE_Products"
    COMPOSITE_FOLDER = "Source_LS_Composites"
    QC_FOLDER = "QC_Masks"
    SWIR2_FOLDER = "SWIR_2_LS"
    
    roi = load_roi(shapefile_path)
    current_date = start_date
    
    while current_date <= end_date:
        year, month = current_date.year, current_date.month
        last_day = calendar.monthrange(year, month)[1]
        im_start_date = f"{year}-{month:02d}-01"
        im_end_date = f"{year}-{month:02d}-{last_day:02d}"
        
        try:
            filled_composite, expansion_mask = get_filled_composite_before_dswe(im_start_date, im_end_date, roi)
            dswe_composite = Dswe(filled_composite)
            
            # Check for non-empty result
            if hasattr(dswe_composite, 'size') and dswe_composite.size().getInfo() == 0:
                logging.warning(f"No data available for {year}-{month:02d}.")
            else:
                # Export DSWE
                if export_dswe:
                    export_to_asset(
                        dswe_composite,
                        year,
                        month,
                        roi,
                        f"{asset_folder}/{DSWE_FOLDER}",
                        bands=["dswe"],
                        product_name="DSWE"
                    )
                
                # Export QC raster
                if export_qc:
                    export_to_asset(
                        expansion_mask,
                        year,
                        month,
                        roi,
                        f"{asset_folder}/{QC_FOLDER}",
                        bands=["expansion_mask"],
                        product_name="QC"
                    )
                
                # Export RGB Landsat composite
                if export_composite:
                    export_to_asset(
                        filled_composite,
                        year,
                        month,
                        roi,
                        f"{asset_folder}/{COMPOSITE_FOLDER}",
                        bands=["Blue", "Green", "Red"],
                        product_name="Composite"
                    )
                
                # Export SWIR2 band
                if export_swir2:
                    export_to_asset(
                        filled_composite,
                        year,
                        month,
                        roi,
                        f"{asset_folder}/{SWIR2_FOLDER}",
                        bands=["Swir2"],
                        product_name="SWIR2"
                    )
                    
        except Exception as e:
            logging.warning(f"Failed to process {year}-{month:02d}: {e}")
        
        # Move to first of the next month
        current_date = (current_date.replace(day=28) + timedelta(days=4)).replace(day=1)

# %% [markdown]
# # Input parameters and export masks as GEE assets

# %%
# User-defined parameters
start_date = datetime(2025, 11, 1)
end_date = datetime(2025, 12, 31)
dswe_level = 4
study_area_path = r"D:\Okavango\Data\StudyAreas\Delta_UCB\Delta_UCB_WGS84.shp"
gee_asset_output_folder = "projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v4"
export_dswe=True
export_qc=True
export_composite=True
export_swir2=False

# Process
process_monthly_dswe(
    start_date, 
    end_date, 
    study_area_path, 
    dswe_level, 
    gee_asset_output_folder,
    export_dswe=export_dswe,
    export_qc=export_qc,
    export_composite=export_composite,
    export_swir2=export_swir2
)
# Out:
# 2025-12-29 17:57:46,921 - WARNING - Failed to process 1984-01: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:57:47,448 - WARNING - Failed to process 1984-02: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:57:47,782 - WARNING - Failed to process 1984-03: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:57:48,717 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_04...
# 2025-12-29 17:57:54,918 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_05...
# 2025-12-29 17:57:56,148 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_06...
# 2025-12-29 17:57:57,195 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_07...
# 2025-12-29 17:57:58,210 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_08...
# 2025-12-29 17:57:58,476 - WARNING - Failed to process 1984-09: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:57:59,389 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_10...
# 2025-12-29 17:58:00,764 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_11...
# 2025-12-29 17:58:01,719 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1984_12...
# 2025-12-29 17:58:03,181 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_01...
# 2025-12-29 17:58:03,964 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_02...
# 2025-12-29 17:58:04,853 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_03...
# 2025-12-29 17:58:05,834 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_04...
# 2025-12-29 17:58:06,305 - WARNING - Failed to process 1985-05: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:58:07,345 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_06...
# 2025-12-29 17:58:08,286 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_07...
# 2025-12-29 17:58:09,443 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_08...
# 2025-12-29 17:58:10,284 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_09...
# 2025-12-29 17:58:10,962 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_10...
# 2025-12-29 17:58:11,712 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_11...
# 2025-12-29 17:58:26,652 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1985_12...
# 2025-12-29 17:58:27,591 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_01...
# 2025-12-29 17:58:29,124 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_02...
# 2025-12-29 17:58:30,261 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_03...
# 2025-12-29 17:58:31,201 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_04...
# 2025-12-29 17:58:32,052 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_05...
# 2025-12-29 17:58:33,549 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_06...
# 2025-12-29 17:58:35,796 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_07...
# 2025-12-29 17:58:37,576 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_08...
# 2025-12-29 17:58:38,567 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_09...
# 2025-12-29 17:58:40,936 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_10...
# 2025-12-29 17:58:41,923 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_11...
# 2025-12-29 17:58:45,422 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1986_12...
# 2025-12-29 17:58:47,745 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_01...
# 2025-12-29 17:58:52,432 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_02...
# 2025-12-29 17:58:53,202 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_03...
# 2025-12-29 17:58:54,181 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_04...
# 2025-12-29 17:58:55,037 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_05...
# 2025-12-29 17:58:55,948 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_06...
# 2025-12-29 17:58:57,046 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_07...
# 2025-12-29 17:58:57,984 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_08...
# 2025-12-29 17:58:58,851 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_09...
# 2025-12-29 17:58:59,850 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1987_10...
# 2025-12-29 17:59:00,111 - WARNING - Failed to process 1987-11: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:59:00,290 - WARNING - Failed to process 1987-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:59:00,552 - WARNING - Failed to process 1988-01: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:59:01,106 - WARNING - Failed to process 1988-02: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:59:01,987 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_03...
# 2025-12-29 17:59:02,822 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_04...
# 2025-12-29 17:59:04,468 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_05...
# 2025-12-29 17:59:11,498 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_06...
# 2025-12-29 17:59:12,579 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_07...
# 2025-12-29 17:59:13,386 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_08...
# 2025-12-29 17:59:14,315 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_09...
# 2025-12-29 17:59:16,385 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_10...
# 2025-12-29 17:59:16,615 - WARNING - Failed to process 1988-11: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 17:59:26,836 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1988_12...
# 2025-12-29 17:59:28,659 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_01...
# 2025-12-29 17:59:30,650 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_02...
# 2025-12-29 17:59:32,337 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_03...
# 2025-12-29 17:59:33,539 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_04...
# 2025-12-29 17:59:34,431 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_05...
# 2025-12-29 17:59:36,006 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_06...
# 2025-12-29 17:59:37,006 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_07...
# 2025-12-29 17:59:37,901 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_08...
# 2025-12-29 17:59:42,383 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_09...
# 2025-12-29 17:59:43,179 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_10...
# 2025-12-29 17:59:45,212 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_11...
# 2025-12-29 17:59:46,860 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1989_12...
# 2025-12-29 17:59:48,377 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_01...
# 2025-12-29 17:59:49,209 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_02...
# 2025-12-29 17:59:50,036 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_03...
# 2025-12-29 17:59:51,056 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_04...
# 2025-12-29 17:59:52,027 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_05...
# 2025-12-29 17:59:53,626 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_06...
# 2025-12-29 17:59:54,931 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_07...
# 2025-12-29 18:00:11,011 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_08...
# 2025-12-29 18:00:11,798 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_09...
# 2025-12-29 18:00:12,995 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1990_10...
# 2025-12-29 18:00:13,244 - WARNING - Failed to process 1990-11: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:00:13,430 - WARNING - Failed to process 1990-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:00:25,972 - WARNING - Failed to process 1991-01: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:00:26,215 - WARNING - Failed to process 1991-02: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:00:27,208 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_03...
# 2025-12-29 18:00:28,075 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_04...
# 2025-12-29 18:00:28,922 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_05...
# 2025-12-29 18:00:30,377 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_06...
# 2025-12-29 18:00:31,182 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_07...
# 2025-12-29 18:00:35,398 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_08...
# 2025-12-29 18:00:36,244 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_09...
# 2025-12-29 18:00:37,084 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_10...
# 2025-12-29 18:00:37,852 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_11...
# 2025-12-29 18:00:41,477 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1991_12...
# 2025-12-29 18:00:42,279 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_01...
# 2025-12-29 18:00:43,467 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_02...
# 2025-12-29 18:00:44,318 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_03...
# 2025-12-29 18:00:45,295 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_04...
# 2025-12-29 18:00:46,051 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_05...
# 2025-12-29 18:00:46,868 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_06...
# 2025-12-29 18:00:47,767 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_07...
# 2025-12-29 18:00:48,599 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_08...
# 2025-12-29 18:00:49,310 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_09...
# 2025-12-29 18:00:50,095 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_10...
# 2025-12-29 18:00:50,960 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_11...
# 2025-12-29 18:00:51,680 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1992_12...
# 2025-12-29 18:00:52,498 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_01...
# 2025-12-29 18:00:53,337 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_02...
# 2025-12-29 18:00:54,308 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_03...
# 2025-12-29 18:00:55,531 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_04...
# 2025-12-29 18:00:56,564 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_05...
# 2025-12-29 18:00:57,355 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_06...
# 2025-12-29 18:00:58,167 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_07...
# 2025-12-29 18:00:58,949 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_08...
# 2025-12-29 18:00:59,716 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_09...
# 2025-12-29 18:01:00,495 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_10...
# 2025-12-29 18:01:01,253 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_11...
# 2025-12-29 18:01:02,037 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1993_12...
# 2025-12-29 18:01:03,793 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_01...
# 2025-12-29 18:01:04,977 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_02...
# 2025-12-29 18:01:05,951 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_03...
# 2025-12-29 18:01:06,937 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_04...
# 2025-12-29 18:01:07,910 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_05...
# 2025-12-29 18:01:08,659 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_06...
# 2025-12-29 18:01:09,451 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_07...
# 2025-12-29 18:01:10,529 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_08...
# 2025-12-29 18:01:11,205 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_09...
# 2025-12-29 18:01:11,966 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_10...
# 2025-12-29 18:01:12,696 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_11...
# 2025-12-29 18:01:13,897 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1994_12...
# 2025-12-29 18:01:14,801 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_01...
# 2025-12-29 18:01:19,283 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_02...
# 2025-12-29 18:01:20,569 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_03...
# 2025-12-29 18:01:21,361 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_04...
# 2025-12-29 18:01:22,068 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_05...
# 2025-12-29 18:01:22,755 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_06...
# 2025-12-29 18:01:23,567 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_07...
# 2025-12-29 18:01:24,272 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_08...
# 2025-12-29 18:01:25,353 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_09...
# 2025-12-29 18:01:26,248 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_10...
# 2025-12-29 18:01:27,032 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_11...
# 2025-12-29 18:01:29,509 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1995_12...
# 2025-12-29 18:01:30,720 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_01...
# 2025-12-29 18:01:31,444 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_02...
# 2025-12-29 18:01:32,160 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_03...
# 2025-12-29 18:01:32,951 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_04...
# 2025-12-29 18:01:33,777 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_05...
# 2025-12-29 18:01:34,580 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_06...
# 2025-12-29 18:01:35,928 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_07...
# 2025-12-29 18:01:36,848 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_08...
# 2025-12-29 18:01:37,603 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_09...
# 2025-12-29 18:01:38,584 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_10...
# 2025-12-29 18:01:39,850 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_11...
# 2025-12-29 18:01:41,062 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1996_12...
# 2025-12-29 18:01:42,518 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_01...
# 2025-12-29 18:01:43,236 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_02...
# 2025-12-29 18:01:43,997 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_03...
# 2025-12-29 18:01:44,976 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_04...
# 2025-12-29 18:01:45,841 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_05...
# 2025-12-29 18:01:46,875 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_06...
# 2025-12-29 18:01:47,743 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_07...
# 2025-12-29 18:01:48,496 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_08...
# 2025-12-29 18:01:49,225 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_09...
# 2025-12-29 18:01:50,017 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_10...
# 2025-12-29 18:01:51,755 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_11...
# 2025-12-29 18:01:52,508 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1997_12...
# 2025-12-29 18:01:53,244 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_01...
# 2025-12-29 18:01:54,532 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_02...
# 2025-12-29 18:01:55,511 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_03...
# 2025-12-29 18:01:56,496 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_04...
# 2025-12-29 18:01:57,442 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_05...
# 2025-12-29 18:01:58,217 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_06...
# 2025-12-29 18:01:58,994 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_07...
# 2025-12-29 18:01:59,818 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_08...
# 2025-12-29 18:02:00,567 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_09...
# 2025-12-29 18:02:01,374 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_10...
# 2025-12-29 18:02:04,274 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_11...
# 2025-12-29 18:02:05,195 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1998_12...
# 2025-12-29 18:02:06,589 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_01...
# 2025-12-29 18:02:07,966 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_02...
# 2025-12-29 18:02:09,250 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_03...
# 2025-12-29 18:02:09,912 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_04...
# 2025-12-29 18:02:11,170 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_05...
# 2025-12-29 18:02:12,311 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_06...
# 2025-12-29 18:02:13,234 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_07...
# 2025-12-29 18:02:14,122 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_08...
# 2025-12-29 18:02:14,881 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_09...
# 2025-12-29 18:02:16,234 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_10...
# 2025-12-29 18:02:17,217 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_11...
# 2025-12-29 18:02:20,150 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_1999_12...
# 2025-12-29 18:02:20,916 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_01...
# 2025-12-29 18:02:22,106 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_02...
# 2025-12-29 18:02:23,634 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_03...
# 2025-12-29 18:02:24,367 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_04...
# 2025-12-29 18:02:25,155 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_05...
# 2025-12-29 18:02:26,454 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_06...
# 2025-12-29 18:02:27,471 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_07...
# 2025-12-29 18:02:28,296 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_08...
# 2025-12-29 18:02:29,125 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_09...
# 2025-12-29 18:02:32,312 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_10...
# 2025-12-29 18:02:33,031 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_11...
# 2025-12-29 18:02:33,732 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2000_12...
# 2025-12-29 18:02:34,401 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_01...
# 2025-12-29 18:02:35,450 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_02...
# 2025-12-29 18:02:37,137 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_03...
# 2025-12-29 18:02:39,461 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_04...
# 2025-12-29 18:02:40,127 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_05...
# 2025-12-29 18:02:40,889 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_06...
# 2025-12-29 18:02:43,839 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_07...
# 2025-12-29 18:02:44,674 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_08...
# 2025-12-29 18:02:45,564 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_09...
# 2025-12-29 18:02:46,969 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_10...
# 2025-12-29 18:02:48,423 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_11...
# 2025-12-29 18:02:49,393 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2001_12...
# 2025-12-29 18:02:50,364 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_01...
# 2025-12-29 18:02:56,298 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_02...
# 2025-12-29 18:02:57,128 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_03...
# 2025-12-29 18:02:57,973 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_04...
# 2025-12-29 18:02:58,721 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_05...
# 2025-12-29 18:02:59,400 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_06...
# 2025-12-29 18:03:00,156 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_07...
# 2025-12-29 18:03:00,902 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_08...
# 2025-12-29 18:03:01,897 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_09...
# 2025-12-29 18:03:02,787 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_10...
# 2025-12-29 18:03:03,515 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_11...
# 2025-12-29 18:03:04,162 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2002_12...
# 2025-12-29 18:03:05,324 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_01...
# 2025-12-29 18:03:06,339 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_02...
# 2025-12-29 18:03:07,194 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_03...
# 2025-12-29 18:03:09,407 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_04...
# 2025-12-29 18:03:10,295 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_05...
# 2025-12-29 18:03:13,562 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_06...
# 2025-12-29 18:03:14,747 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_07...
# 2025-12-29 18:03:16,425 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_08...
# 2025-12-29 18:03:17,163 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_09...
# 2025-12-29 18:03:17,916 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_10...
# 2025-12-29 18:03:18,680 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_11...
# 2025-12-29 18:03:20,101 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2003_12...
# 2025-12-29 18:03:27,657 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_01...
# 2025-12-29 18:03:28,525 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_02...
# 2025-12-29 18:03:29,192 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_03...
# 2025-12-29 18:03:30,009 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_04...
# 2025-12-29 18:03:30,693 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_05...
# 2025-12-29 18:03:38,055 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_06...
# 2025-12-29 18:03:39,051 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_07...
# 2025-12-29 18:03:39,818 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_08...
# 2025-12-29 18:03:40,618 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_09...
# 2025-12-29 18:03:41,449 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_10...
# 2025-12-29 18:03:42,343 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_11...
# 2025-12-29 18:03:43,086 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2004_12...
# 2025-12-29 18:03:44,187 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_01...
# 2025-12-29 18:03:46,473 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_02...
# 2025-12-29 18:03:47,138 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_03...
# 2025-12-29 18:03:47,944 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_04...
# 2025-12-29 18:03:48,825 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_05...
# 2025-12-29 18:03:49,592 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_06...
# 2025-12-29 18:03:50,260 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_07...
# 2025-12-29 18:03:51,088 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_08...
# 2025-12-29 18:03:52,194 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_09...
# 2025-12-29 18:03:52,962 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_10...
# 2025-12-29 18:03:53,735 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2005_11...
# 2025-12-29 18:03:53,912 - WARNING - Failed to process 2005-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:03:54,680 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_01...
# 2025-12-29 18:03:55,529 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_02...
# 2025-12-29 18:03:57,114 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_03...
# 2025-12-29 18:03:58,398 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_04...
# 2025-12-29 18:03:59,318 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_05...
# 2025-12-29 18:04:01,551 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_06...
# 2025-12-29 18:04:02,325 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_07...
# 2025-12-29 18:04:02,956 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_08...
# 2025-12-29 18:04:03,750 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_09...
# 2025-12-29 18:04:05,107 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_10...
# 2025-12-29 18:04:06,022 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_11...
# 2025-12-29 18:04:07,039 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2006_12...
# 2025-12-29 18:04:08,071 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_01...
# 2025-12-29 18:04:08,961 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_02...
# 2025-12-29 18:04:09,760 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_03...
# 2025-12-29 18:04:10,559 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_04...
# 2025-12-29 18:04:11,310 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_05...
# 2025-12-29 18:04:11,992 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_06...
# 2025-12-29 18:04:12,699 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_07...
# 2025-12-29 18:04:13,432 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_08...
# 2025-12-29 18:04:14,544 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_09...
# 2025-12-29 18:04:15,377 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2007_10...
# 2025-12-29 18:04:15,550 - WARNING - Failed to process 2007-11: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:04:15,849 - WARNING - Failed to process 2007-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:04:17,216 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_01...
# 2025-12-29 18:04:18,281 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_02...
# 2025-12-29 18:04:19,185 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_03...
# 2025-12-29 18:04:19,950 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_04...
# 2025-12-29 18:04:20,707 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_05...
# 2025-12-29 18:04:21,366 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_06...
# 2025-12-29 18:04:22,220 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_07...
# 2025-12-29 18:04:23,050 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_08...
# 2025-12-29 18:04:23,785 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_09...
# 2025-12-29 18:04:24,537 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_10...
# 2025-12-29 18:04:25,630 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2008_11...
# 2025-12-29 18:04:25,857 - WARNING - Failed to process 2008-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:04:32,010 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_01...
# 2025-12-29 18:04:32,678 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_02...
# 2025-12-29 18:04:33,795 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_03...
# 2025-12-29 18:04:34,530 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_04...
# 2025-12-29 18:04:35,391 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_05...
# 2025-12-29 18:04:36,231 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_06...
# 2025-12-29 18:04:37,122 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_07...
# 2025-12-29 18:04:37,907 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_08...
# 2025-12-29 18:04:38,711 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_09...
# 2025-12-29 18:04:39,850 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_10...
# 2025-12-29 18:04:40,482 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_11...
# 2025-12-29 18:04:41,284 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2009_12...
# 2025-12-29 18:04:43,437 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_01...
# 2025-12-29 18:04:44,169 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_02...
# 2025-12-29 18:04:45,038 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_03...
# 2025-12-29 18:04:45,919 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_04...
# 2025-12-29 18:04:46,790 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_05...
# 2025-12-29 18:04:47,425 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_06...
# 2025-12-29 18:04:48,173 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_07...
# 2025-12-29 18:04:48,801 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_08...
# 2025-12-29 18:04:49,608 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_09...
# 2025-12-29 18:04:50,244 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_10...
# 2025-12-29 18:04:50,892 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_11...
# 2025-12-29 18:04:52,397 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2010_12...
# 2025-12-29 18:04:53,450 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_01...
# 2025-12-29 18:04:56,797 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_02...
# 2025-12-29 18:04:57,997 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_03...
# 2025-12-29 18:04:58,731 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_04...
# 2025-12-29 18:04:59,450 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_05...
# 2025-12-29 18:05:00,147 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_06...
# 2025-12-29 18:05:00,933 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_07...
# 2025-12-29 18:05:01,707 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_08...
# 2025-12-29 18:05:03,887 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_09...
# 2025-12-29 18:05:04,622 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_10...
# 2025-12-29 18:05:05,742 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2011_11...
# 2025-12-29 18:05:05,972 - WARNING - Failed to process 2011-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:07,301 - WARNING - Failed to process 2012-01: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:07,557 - WARNING - Failed to process 2012-02: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:07,804 - WARNING - Failed to process 2012-03: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:08,024 - WARNING - Failed to process 2012-04: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:08,215 - WARNING - Failed to process 2012-05: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:08,424 - WARNING - Failed to process 2012-06: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:08,656 - WARNING - Failed to process 2012-07: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:08,839 - WARNING - Failed to process 2012-08: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:09,035 - WARNING - Failed to process 2012-09: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:09,206 - WARNING - Failed to process 2012-10: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:09,440 - WARNING - Failed to process 2012-11: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:09,658 - WARNING - Failed to process 2012-12: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:09,813 - WARNING - Failed to process 2013-01: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:10,012 - WARNING - Failed to process 2013-02: Image.select: Band pattern 'Green' was applied to an Image with no bands. See https://developers.google.com/earth-engine/guides/debugging#no-bands
# 2025-12-29 18:05:10,811 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_03...
# 2025-12-29 18:05:11,561 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_04...
# 2025-12-29 18:05:12,290 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_05...
# 2025-12-29 18:05:12,956 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_06...
# 2025-12-29 18:05:13,665 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_07...
# 2025-12-29 18:05:14,394 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_08...
# 2025-12-29 18:05:15,230 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_09...
# 2025-12-29 18:05:16,165 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2013_10...
# ...
# 2025-12-29 18:05:55,529 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_06...
# 2025-12-29 18:05:56,516 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_07...
# 2025-12-29 18:05:57,380 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_08...
# 2025-12-29 18:05:58,197 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_09...
# 2025-12-29 18:05:58,968 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_10...
# 2025-12-29 18:05:59,735 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_11...
# 2025-12-29 18:06:00,467 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2015_12...
# 2025-12-29 18:06:01,304 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_01...
# 2025-12-29 18:06:02,055 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_02...
# 2025-12-29 18:06:03,051 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_03...
# 2025-12-29 18:06:03,768 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_04...
# 2025-12-29 18:06:04,537 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_05...
# 2025-12-29 18:06:28,335 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_06...
# 2025-12-29 18:06:29,117 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_07...
# 2025-12-29 18:06:30,684 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_08...
# 2025-12-29 18:06:31,576 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_09...
# 2025-12-29 18:06:32,278 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_10...
# 2025-12-29 18:06:33,045 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_11...
# 2025-12-29 18:06:33,709 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2016_12...
# 2025-12-29 18:06:34,661 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_01...
# 2025-12-29 18:06:35,524 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_02...
# 2025-12-29 18:06:37,076 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_03...
# 2025-12-29 18:06:38,009 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_04...
# 2025-12-29 18:06:38,785 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_05...
# 2025-12-29 18:06:39,483 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_06...
# 2025-12-29 18:06:41,355 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_07...
# 2025-12-29 18:06:42,107 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_08...
# 2025-12-29 18:06:43,012 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_09...
# 2025-12-29 18:06:43,740 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_10...
# 2025-12-29 18:06:44,370 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_11...
# 2025-12-29 18:06:45,120 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2017_12...
# 2025-12-29 18:06:46,139 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_01...
# 2025-12-29 18:06:46,906 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_02...
# 2025-12-29 18:06:47,671 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_03...
# 2025-12-29 18:06:48,390 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_04...
# 2025-12-29 18:06:49,165 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_05...
# 2025-12-29 18:06:49,898 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_06...
# 2025-12-29 18:06:50,876 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_07...
# 2025-12-29 18:06:51,509 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_08...
# 2025-12-29 18:06:52,241 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_09...
# 2025-12-29 18:06:52,961 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_10...
# 2025-12-29 18:06:53,667 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_11...
# 2025-12-29 18:06:54,408 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2018_12...
# 2025-12-29 18:06:55,099 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_01...
# 2025-12-29 18:06:55,897 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_02...
# 2025-12-29 18:06:56,933 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_03...
# 2025-12-29 18:06:57,821 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_04...
# 2025-12-29 18:06:58,633 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_05...
# 2025-12-29 18:06:59,214 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_06...
# 2025-12-29 18:07:06,362 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_07...
# 2025-12-29 18:07:07,634 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_08...
# 2025-12-29 18:07:08,357 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_09...
# 2025-12-29 18:07:09,097 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_10...
# 2025-12-29 18:07:09,731 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_11...
# 2025-12-29 18:07:10,843 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2019_12...
# 2025-12-29 18:07:11,489 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_01...
# 2025-12-29 18:07:12,060 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_02...
# 2025-12-29 18:07:12,742 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_03...
# 2025-12-29 18:07:15,985 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_04...
# 2025-12-29 18:07:16,796 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_05...
# 2025-12-29 18:07:17,662 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_06...
# 2025-12-29 18:07:18,482 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_07...
# 2025-12-29 18:07:19,342 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_08...
# 2025-12-29 18:07:20,039 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_09...
# 2025-12-29 18:07:20,781 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_10...
# 2025-12-29 18:07:21,585 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_11...
# 2025-12-29 18:07:22,334 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2020_12...
# 2025-12-29 18:07:22,986 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_01...
# 2025-12-29 18:07:23,827 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_02...
# 2025-12-29 18:07:24,849 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_03...
# 2025-12-29 18:07:25,805 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_04...
# 2025-12-29 18:07:26,714 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_05...
# 2025-12-29 18:07:27,487 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_06...
# 2025-12-29 18:07:28,207 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_07...
# 2025-12-29 18:07:28,921 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_08...
# 2025-12-29 18:07:29,558 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_09...
# 2025-12-29 18:07:30,642 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_10...
# 2025-12-29 18:07:32,028 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_11...
# 2025-12-29 18:07:32,702 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2021_12...
# 2025-12-29 18:07:33,328 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_01...
# 2025-12-29 18:07:33,960 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_02...
# 2025-12-29 18:07:34,711 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_03...
# 2025-12-29 18:07:35,519 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_04...
# 2025-12-29 18:07:36,349 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_05...
# 2025-12-29 18:07:37,279 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_06...
# 2025-12-29 18:07:38,164 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_07...
# 2025-12-29 18:07:38,934 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_08...
# 2025-12-29 18:07:39,637 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_09...
# 2025-12-29 18:07:40,540 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_10...
# 2025-12-29 18:07:41,449 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_11...
# 2025-12-29 18:07:42,129 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2022_12...
# 2025-12-29 18:07:42,785 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_01...
# 2025-12-29 18:07:45,320 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_02...
# 2025-12-29 18:07:46,139 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_03...
# 2025-12-29 18:07:46,905 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_04...
# 2025-12-29 18:07:47,683 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_05...
# 2025-12-29 18:07:48,473 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_06...
# 2025-12-29 18:07:49,172 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_07...
# 2025-12-29 18:07:49,894 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_08...
# 2025-12-29 18:07:50,690 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_09...
# 2025-12-29 18:07:51,383 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_10...
# 2025-12-29 18:07:52,227 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_11...
# 2025-12-29 18:07:52,949 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2023_12...
# 2025-12-29 18:07:53,613 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_01...
# 2025-12-29 18:07:54,360 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_02...
# 2025-12-29 18:07:55,046 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_03...
# 2025-12-29 18:07:55,914 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_04...
# 2025-12-29 18:07:56,786 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_05...
# 2025-12-29 18:07:57,580 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_06...
# 2025-12-29 18:07:58,381 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_07...
# 2025-12-29 18:07:59,232 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_08...
# 2025-12-29 18:08:00,112 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_09...
# 2025-12-29 18:08:00,877 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_10...
# 2025-12-29 18:08:01,627 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_11...
# 2025-12-29 18:08:02,350 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2024_12...
# 2025-12-29 18:08:03,016 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_01...
# 2025-12-29 18:08:03,737 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_02...
# 2025-12-29 18:08:07,450 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_03...
# 2025-12-29 18:08:08,230 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_04...
# 2025-12-29 18:08:09,031 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_05...
# 2025-12-29 18:08:09,800 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_06...
# 2025-12-29 18:08:10,526 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_07...
# 2025-12-29 18:08:11,261 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_08...
# 2025-12-29 18:08:12,037 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_09...
# 2025-12-29 18:08:12,800 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_10...
# 2025-12-29 18:08:13,682 - INFO - Exporting projects/phd-work2023/assets/Kern_Images/Source_LS_Composites/Composite_2025_11...

# %% [markdown]
# ## Monitor GEE tasks

# %%
# Get list of all running GEE tasks
task_list = ee.batch.Task.list()

# Print task statuses
for task in task_list:
    print(f"Task: {task.status()['description']}, Status: {task.status()['state']}")
# Out:
# Task: SWIR2_2025_09, Status: READY
# Task: SWIR2_2025_08, Status: READY
# Task: SWIR2_2025_07, Status: READY
# Task: SWIR2_2025_06, Status: READY
# Task: SWIR2_2025_05, Status: READY
# Task: SWIR2_2025_04, Status: READY
# Task: SWIR2_2025_03, Status: READY
# Task: SWIR2_2025_02, Status: READY
# Task: SWIR2_2025_01, Status: READY
# Task: SWIR2_2024_12, Status: READY
# Task: SWIR2_2024_11, Status: READY
# Task: SWIR2_2024_10, Status: READY
# Task: SWIR2_2024_09, Status: READY
# Task: SWIR2_2024_08, Status: READY
# Task: SWIR2_2024_07, Status: READY
# Task: SWIR2_2024_06, Status: READY
# Task: SWIR2_2024_05, Status: READY
# Task: SWIR2_2024_04, Status: READY
# Task: SWIR2_2024_03, Status: READY
# Task: SWIR2_2024_02, Status: READY
# Task: SWIR2_2024_01, Status: READY
# Task: SWIR2_2023_12, Status: READY
# Task: SWIR2_2023_11, Status: READY
# Task: SWIR2_2023_10, Status: READY
# Task: SWIR2_2023_09, Status: READY
# Task: SWIR2_2023_08, Status: READY
# Task: SWIR2_2023_07, Status: READY
# Task: SWIR2_2023_06, Status: READY
# Task: SWIR2_2023_05, Status: READY
# Task: SWIR2_2023_04, Status: READY
# Task: SWIR2_2023_03, Status: READY
# Task: SWIR2_2023_02, Status: READY
# Task: SWIR2_2023_01, Status: READY
# Task: SWIR2_2022_12, Status: READY
# Task: SWIR2_2022_11, Status: READY
# Task: SWIR2_2022_10, Status: READY
# Task: SWIR2_2022_09, Status: READY
# Task: SWIR2_2022_08, Status: READY
# Task: SWIR2_2022_07, Status: READY
# Task: SWIR2_2022_06, Status: READY
# Task: SWIR2_2022_05, Status: READY
# Task: SWIR2_2022_04, Status: READY
# Task: SWIR2_2022_03, Status: READY
# Task: SWIR2_2022_02, Status: READY
# Task: SWIR2_2022_01, Status: READY
# Task: SWIR2_2021_12, Status: READY
# Task: SWIR2_2021_11, Status: READY
# Task: SWIR2_2021_10, Status: READY
# Task: SWIR2_2021_09, Status: READY
# Task: SWIR2_2021_08, Status: READY
# Task: SWIR2_2021_07, Status: READY
# Task: SWIR2_2021_06, Status: READY
# Task: SWIR2_2021_05, Status: READY
# Task: SWIR2_2021_04, Status: READY
# Task: SWIR2_2021_03, Status: READY
# Task: SWIR2_2021_02, Status: READY
# Task: SWIR2_2021_01, Status: READY
# Task: SWIR2_2020_12, Status: READY
# Task: SWIR2_2020_11, Status: READY
# Task: SWIR2_2020_10, Status: READY
# Task: SWIR2_2020_09, Status: READY
# Task: SWIR2_2020_08, Status: READY
# Task: SWIR2_2020_07, Status: READY
# Task: SWIR2_2020_06, Status: READY
# Task: SWIR2_2020_05, Status: READY
# Task: SWIR2_2020_04, Status: READY
# Task: SWIR2_2020_03, Status: READY
# Task: SWIR2_2020_02, Status: READY
# Task: SWIR2_2020_01, Status: READY
# Task: SWIR2_2019_12, Status: READY
# Task: SWIR2_2019_11, Status: READY
# Task: SWIR2_2019_10, Status: READY
# Task: SWIR2_2019_09, Status: READY
# Task: SWIR2_2019_08, Status: READY
# Task: SWIR2_2019_07, Status: READY
# Task: SWIR2_2019_06, Status: READY
# Task: SWIR2_2019_05, Status: READY
# Task: SWIR2_2019_04, Status: READY
# Task: SWIR2_2019_03, Status: READY
# Task: SWIR2_2019_02, Status: READY
# Task: SWIR2_2019_01, Status: READY
# Task: SWIR2_2018_12, Status: READY
# Task: SWIR2_2018_11, Status: READY
# Task: SWIR2_2018_10, Status: READY
# Task: SWIR2_2018_09, Status: READY
# Task: SWIR2_2018_08, Status: READY
# Task: SWIR2_2018_07, Status: READY
# Task: SWIR2_2018_06, Status: READY
# Task: SWIR2_2018_05, Status: READY
# Task: SWIR2_2018_04, Status: READY
# Task: SWIR2_2018_03, Status: READY
# Task: SWIR2_2018_02, Status: READY
# Task: SWIR2_2018_01, Status: READY
# Task: SWIR2_2017_12, Status: READY
# Task: SWIR2_2017_11, Status: READY
# Task: SWIR2_2017_10, Status: READY
# Task: SWIR2_2017_09, Status: READY
# Task: SWIR2_2017_08, Status: READY
# Task: SWIR2_2017_07, Status: READY
# Task: SWIR2_2017_06, Status: READY
# Task: SWIR2_2017_05, Status: READY
# Task: SWIR2_2017_04, Status: READY
# Task: SWIR2_2017_03, Status: READY
# Task: SWIR2_2017_02, Status: READY
# Task: SWIR2_2017_01, Status: READY
# Task: SWIR2_2016_12, Status: READY
# Task: SWIR2_2016_11, Status: READY
# Task: SWIR2_2016_10, Status: READY
# Task: SWIR2_2016_09, Status: READY
# Task: SWIR2_2016_08, Status: READY
# Task: SWIR2_2016_07, Status: READY
# Task: SWIR2_2016_06, Status: READY
# Task: SWIR2_2016_05, Status: READY
# Task: SWIR2_2016_04, Status: READY
# Task: SWIR2_2016_03, Status: READY
# Task: SWIR2_2016_02, Status: READY
# Task: SWIR2_2016_01, Status: READY
# Task: SWIR2_2015_12, Status: READY
# Task: SWIR2_2015_11, Status: READY
# Task: SWIR2_2015_10, Status: READY
# Task: SWIR2_2015_09, Status: READY
# Task: SWIR2_2015_08, Status: READY
# Task: SWIR2_2015_07, Status: READY
# Task: SWIR2_2015_06, Status: READY
# Task: SWIR2_2015_05, Status: READY
# Task: SWIR2_2015_04, Status: READY
# Task: SWIR2_2015_03, Status: READY
# Task: SWIR2_2015_02, Status: READY
# Task: SWIR2_2015_01, Status: READY
# Task: SWIR2_2014_12, Status: READY
# Task: SWIR2_2014_11, Status: READY
# Task: SWIR2_2014_10, Status: READY
# Task: SWIR2_2014_09, Status: READY
# Task: SWIR2_2014_08, Status: READY
# Task: SWIR2_2014_07, Status: READY
# Task: SWIR2_2014_06, Status: READY
# Task: SWIR2_2014_05, Status: READY
# Task: SWIR2_2014_04, Status: READY
# Task: SWIR2_2014_03, Status: READY
# Task: SWIR2_2014_02, Status: READY
# Task: SWIR2_2014_01, Status: READY
# Task: SWIR2_2013_12, Status: READY
# Task: SWIR2_2013_11, Status: READY
# Task: SWIR2_2013_10, Status: READY
# Task: SWIR2_2013_09, Status: READY
# Task: SWIR2_2013_08, Status: READY
# Task: SWIR2_2013_07, Status: READY
# Task: SWIR2_2013_06, Status: READY
# Task: SWIR2_2013_05, Status: READY
# Task: SWIR2_2013_04, Status: READY
# Task: SWIR2_2013_03, Status: READY
# Task: SWIR2_2011_03, Status: READY
# Task: SWIR2_2011_02, Status: READY
# Task: SWIR2_2011_01, Status: READY
# Task: SWIR2_2010_12, Status: READY
# Task: SWIR2_2010_05, Status: READY
# Task: SWIR2_2010_04, Status: READY
# Task: SWIR2_2010_03, Status: READY
# Task: SWIR2_2010_02, Status: READY
# Task: SWIR2_2010_01, Status: READY
# Task: SWIR2_2009_12, Status: READY
# Task: SWIR2_2009_11, Status: READY
# Task: SWIR2_2009_05, Status: READY
# Task: SWIR2_2009_04, Status: READY
# Task: SWIR2_2009_03, Status: READY
# Task: SWIR2_2008_10, Status: READY
# Task: SWIR2_2008_09, Status: READY
# Task: SWIR2_2008_08, Status: READY
# Task: SWIR2_2008_05, Status: READY
# Task: SWIR2_2008_04, Status: READY
# Task: SWIR2_2008_03, Status: READY
# Task: SWIR2_2008_02, Status: READY
# Task: SWIR2_2007_09, Status: READY
# Task: SWIR2_2007_08, Status: READY
# Task: SWIR2_2007_07, Status: READY
# Task: SWIR2_2007_06, Status: READY
# Task: SWIR2_2007_05, Status: READY
# Task: SWIR2_2007_04, Status: READY
# Task: SWIR2_2007_03, Status: READY
# Task: SWIR2_2007_02, Status: READY
# Task: SWIR2_2007_01, Status: READY
# Task: SWIR2_2006_12, Status: READY
# Task: SWIR2_2006_11, Status: READY
# Task: SWIR2_2006_10, Status: READY
# Task: SWIR2_2006_09, Status: READY
# Task: SWIR2_2006_08, Status: READY
# Task: SWIR2_2006_07, Status: READY
# Task: SWIR2_2006_06, Status: READY
# Task: SWIR2_2006_04, Status: READY
# Task: SWIR2_2006_03, Status: READY
# Task: SWIR2_2006_02, Status: READY
# Task: SWIR2_2005_11, Status: READY
# Task: SWIR2_2005_10, Status: READY
# Task: SWIR2_2005_09, Status: READY
# Task: SWIR2_2005_08, Status: READY
# Task: SWIR2_2005_07, Status: READY
# Task: SWIR2_2005_06, Status: READY
# Task: SWIR2_2005_04, Status: READY
# Task: SWIR2_2005_03, Status: READY
# Task: SWIR2_2005_02, Status: READY
# Task: SWIR2_2004_09, Status: READY
# Task: SWIR2_2004_08, Status: READY
# Task: SWIR2_2004_07, Status: READY
# Task: SWIR2_2004_06, Status: READY
# Task: SWIR2_2004_05, Status: READY
# Task: SWIR2_2004_04, Status: READY
# Task: SWIR2_2004_03, Status: READY
# Task: SWIR2_2004_02, Status: READY
# Task: SWIR2_2003_12, Status: READY
# Task: SWIR2_2003_11, Status: READY
# Task: SWIR2_2003_04, Status: READY
# Task: SWIR2_2003_03, Status: READY
# Task: SWIR2_2003_02, Status: READY
# Task: SWIR2_2003_01, Status: READY
# Task: SWIR2_2002_12, Status: READY
# Task: SWIR2_2002_11, Status: READY
# Task: SWIR2_2002_10, Status: READY
# Task: SWIR2_2002_09, Status: READY
# Task: SWIR2_2002_08, Status: READY
# Task: SWIR2_2002_07, Status: READY
# Task: SWIR2_2002_06, Status: READY
# Task: SWIR2_2002_05, Status: READY
# Task: SWIR2_2002_04, Status: READY
# Task: SWIR2_2002_03, Status: READY
# Task: SWIR2_2002_02, Status: READY
# Task: SWIR2_2002_01, Status: READY
# Task: SWIR2_2001_12, Status: READY
# Task: SWIR2_2001_11, Status: READY
# Task: SWIR2_2001_10, Status: READY
# Task: SWIR2_2001_09, Status: READY
# Task: SWIR2_2001_08, Status: READY
# Task: SWIR2_2001_07, Status: READY
# Task: SWIR2_2001_06, Status: READY
# Task: SWIR2_2001_04, Status: READY
# Task: SWIR2_2001_03, Status: READY
# Task: SWIR2_2001_02, Status: READY
# Task: SWIR2_2001_01, Status: READY
# Task: SWIR2_2000_12, Status: READY
# Task: SWIR2_2000_11, Status: READY
# Task: SWIR2_2000_10, Status: READY
# Task: SWIR2_2000_09, Status: READY
# Task: SWIR2_2000_08, Status: READY
# Task: SWIR2_2000_07, Status: READY
# Task: SWIR2_2000_06, Status: READY
# Task: SWIR2_2000_05, Status: READY
# Task: SWIR2_2000_04, Status: READY
# Task: SWIR2_2000_02, Status: READY
# Task: SWIR2_2000_01, Status: READY
# Task: SWIR2_1999_12, Status: READY
# Task: SWIR2_1999_11, Status: READY
# Task: SWIR2_1999_10, Status: READY
# Task: SWIR2_1999_08, Status: READY
# Task: SWIR2_1999_06, Status: READY
# Task: SWIR2_1999_05, Status: READY
# Task: SWIR2_1999_04, Status: READY
# Task: SWIR2_1999_03, Status: READY
# Task: SWIR2_1999_02, Status: READY
# Task: SWIR2_1999_01, Status: READY
# Task: SWIR2_1998_12, Status: READY
# Task: SWIR2_1998_11, Status: READY
# Task: SWIR2_1998_10, Status: READY
# Task: SWIR2_1998_09, Status: READY
# Task: SWIR2_1998_08, Status: READY
# Task: SWIR2_1998_07, Status: READY
# Task: SWIR2_1998_06, Status: READY
# Task: SWIR2_1998_05, Status: READY
# Task: SWIR2_1998_04, Status: READY
# Task: SWIR2_1998_03, Status: READY
# Task: SWIR2_1998_02, Status: READY
# Task: SWIR2_1998_01, Status: READY
# Task: SWIR2_1997_10, Status: READY
# Task: SWIR2_1997_09, Status: READY
# Task: SWIR2_1997_08, Status: READY
# Task: SWIR2_1997_07, Status: READY
# Task: SWIR2_1997_06, Status: READY
# Task: SWIR2_1997_04, Status: READY
# Task: SWIR2_1997_03, Status: READY
# Task: SWIR2_1997_02, Status: READY
# Task: SWIR2_1997_01, Status: READY
# Task: SWIR2_1996_11, Status: READY
# Task: SWIR2_1996_09, Status: READY
# Task: SWIR2_1996_08, Status: READY
# Task: SWIR2_1996_07, Status: READY
# Task: SWIR2_1996_06, Status: READY
# Task: SWIR2_1996_03, Status: READY
# Task: SWIR2_1996_02, Status: READY
# Task: SWIR2_1996_01, Status: READY
# Task: SWIR2_1995_12, Status: READY
# Task: SWIR2_1995_11, Status: READY
# Task: SWIR2_1995_09, Status: READY
# Task: SWIR2_1995_08, Status: READY
# Task: SWIR2_1995_07, Status: READY
# Task: SWIR2_1995_06, Status: READY
# Task: SWIR2_1995_05, Status: READY
# Task: SWIR2_1995_03, Status: READY
# Task: SWIR2_1995_02, Status: READY
# Task: SWIR2_1995_01, Status: READY
# Task: SWIR2_1994_12, Status: READY
# Task: SWIR2_1994_11, Status: READY
# Task: SWIR2_1994_10, Status: READY
# Task: SWIR2_1994_09, Status: READY
# Task: SWIR2_1994_08, Status: READY
# Task: SWIR2_1994_07, Status: READY
# Task: SWIR2_1994_04, Status: READY
# Task: SWIR2_1994_03, Status: READY
# Task: SWIR2_1994_01, Status: READY
# Task: SWIR2_1993_12, Status: READY
# Task: SWIR2_1993_11, Status: READY
# Task: SWIR2_1993_08, Status: READY
# Task: SWIR2_1993_07, Status: READY
# Task: SWIR2_1993_06, Status: READY
# Task: SWIR2_1993_05, Status: READY
# Task: SWIR2_1993_04, Status: READY
# Task: SWIR2_1993_03, Status: READY
# Task: SWIR2_1993_02, Status: READY
# Task: SWIR2_1993_01, Status: READY
# Task: SWIR2_1992_12, Status: READY
# Task: SWIR2_1992_11, Status: READY
# Task: SWIR2_1992_10, Status: READY
# Task: SWIR2_1992_09, Status: READY
# Task: SWIR2_1992_08, Status: READY
# Task: SWIR2_1992_07, Status: READY
# Task: SWIR2_1992_06, Status: READY
# Task: SWIR2_1992_05, Status: READY
# Task: SWIR2_1992_04, Status: READY
# Task: SWIR2_1992_03, Status: READY
# Task: SWIR2_1992_02, Status: READY
# Task: SWIR2_1992_01, Status: READY
# Task: SWIR2_1991_11, Status: READY
# Task: SWIR2_1991_10, Status: READY
# Task: SWIR2_1991_09, Status: RUNNING
# Task: SWIR2_1991_08, Status: RUNNING
# Task: SWIR2_1991_07, Status: RUNNING
# Task: SWIR2_1991_06, Status: COMPLETED
# Task: SWIR2_1991_05, Status: COMPLETED
# Task: SWIR2_1991_04, Status: COMPLETED
# Task: SWIR2_1991_03, Status: COMPLETED
# Task: SWIR2_1991_02, Status: COMPLETED
# Task: SWIR2_1991_01, Status: COMPLETED
# Task: SWIR2_1990_12, Status: COMPLETED
# Task: SWIR2_1990_11, Status: COMPLETED
# Task: SWIR2_1990_10, Status: COMPLETED
# Task: SWIR2_1990_09, Status: COMPLETED
# Task: SWIR2_1990_08, Status: COMPLETED
# Task: SWIR2_1990_07, Status: COMPLETED
# Task: SWIR2_1990_06, Status: COMPLETED
# Task: SWIR2_1990_05, Status: COMPLETED
# Task: SWIR2_1990_04, Status: COMPLETED
# Task: SWIR2_1990_03, Status: COMPLETED
# Task: SWIR2_1990_02, Status: COMPLETED
# Task: SWIR2_1989_12, Status: COMPLETED
# Task: SWIR2_1989_09, Status: COMPLETED
# Task: SWIR2_1989_08, Status: COMPLETED
# Task: SWIR2_1989_07, Status: COMPLETED
# Task: SWIR2_1989_06, Status: COMPLETED
# Task: SWIR2_1989_05, Status: COMPLETED
# Task: SWIR2_1989_04, Status: COMPLETED
# Task: SWIR2_1989_03, Status: COMPLETED
# Task: SWIR2_1989_02, Status: COMPLETED
# Task: SWIR2_1989_01, Status: COMPLETED
# Task: SWIR2_1987_09, Status: COMPLETED
# Task: SWIR2_1987_08, Status: COMPLETED
# Task: SWIR2_1987_07, Status: COMPLETED
# Task: SWIR2_1987_06, Status: COMPLETED
# Task: SWIR2_1987_03, Status: COMPLETED
# Task: SWIR2_1987_02, Status: COMPLETED
# Task: SWIR2_1987_01, Status: COMPLETED
# Task: SWIR2_1986_12, Status: COMPLETED
# Task: SWIR2_1986_11, Status: COMPLETED
# Task: SWIR2_1985_04, Status: COMPLETED
# Task: SWIR2_1984_11, Status: COMPLETED
# Task: SWIR2_1984_10, Status: COMPLETED
# Task: SWIR2_1984_09, Status: COMPLETED
# Task: SWIR2_1984_07, Status: COMPLETED
# Task: SWIR2_1984_06, Status: COMPLETED
# Task: SWIR2_2025_09, Status: FAILED
# Task: SWIR2_2025_08, Status: FAILED
# Task: SWIR2_2025_07, Status: FAILED
# Task: SWIR2_2025_06, Status: FAILED
# Task: SWIR2_2025_05, Status: FAILED
# Task: SWIR2_2025_04, Status: FAILED
# Task: SWIR2_2025_03, Status: FAILED
# Task: SWIR2_2025_02, Status: FAILED
# Task: SWIR2_2025_01, Status: FAILED
# Task: SWIR2_2024_12, Status: FAILED
# Task: SWIR2_2024_11, Status: FAILED
# Task: SWIR2_2024_10, Status: FAILED
# Task: SWIR2_2024_09, Status: FAILED
# Task: SWIR2_2024_08, Status: FAILED
# Task: SWIR2_2024_07, Status: FAILED
# Task: SWIR2_2024_06, Status: FAILED
# Task: SWIR2_2024_05, Status: FAILED
# Task: SWIR2_2024_04, Status: FAILED
# Task: SWIR2_2024_03, Status: FAILED
# Task: SWIR2_2024_02, Status: FAILED
# Task: SWIR2_2024_01, Status: FAILED
# Task: SWIR2_2023_12, Status: FAILED
# Task: SWIR2_2023_11, Status: FAILED
# Task: SWIR2_2023_10, Status: FAILED
# Task: SWIR2_2023_09, Status: FAILED
# Task: SWIR2_2023_08, Status: FAILED
# Task: SWIR2_2023_07, Status: FAILED
# Task: SWIR2_2023_06, Status: FAILED
# Task: SWIR2_2023_05, Status: FAILED
# Task: SWIR2_2023_04, Status: FAILED
# Task: SWIR2_2023_03, Status: FAILED
# Task: SWIR2_2023_02, Status: FAILED
# Task: SWIR2_2023_01, Status: FAILED
# Task: SWIR2_2022_12, Status: FAILED
# Task: SWIR2_2022_11, Status: FAILED
# Task: SWIR2_2022_10, Status: FAILED
# Task: SWIR2_2022_09, Status: FAILED
# Task: SWIR2_2022_08, Status: FAILED
# Task: SWIR2_2022_07, Status: FAILED
# Task: SWIR2_2022_06, Status: FAILED
# Task: SWIR2_2022_05, Status: FAILED
# Task: SWIR2_2022_04, Status: FAILED
# Task: SWIR2_2022_03, Status: FAILED
# Task: SWIR2_2022_02, Status: FAILED
# Task: SWIR2_2022_01, Status: FAILED
# Task: SWIR2_2021_12, Status: FAILED
# Task: SWIR2_2021_11, Status: FAILED
# Task: SWIR2_2021_10, Status: FAILED
# Task: SWIR2_2021_09, Status: FAILED
# Task: SWIR2_2021_08, Status: FAILED
# Task: SWIR2_2021_07, Status: FAILED
# Task: SWIR2_2021_06, Status: FAILED
# Task: SWIR2_2021_05, Status: FAILED
# Task: SWIR2_2021_04, Status: FAILED
# Task: SWIR2_2021_03, Status: FAILED
# Task: SWIR2_2021_02, Status: FAILED
# Task: SWIR2_2021_01, Status: FAILED
# Task: SWIR2_2020_12, Status: FAILED
# Task: SWIR2_2020_11, Status: FAILED
# Task: SWIR2_2020_10, Status: FAILED
# Task: SWIR2_2020_09, Status: FAILED
# Task: SWIR2_2020_08, Status: FAILED
# Task: SWIR2_2020_07, Status: FAILED
# Task: SWIR2_2020_06, Status: FAILED
# Task: SWIR2_2020_05, Status: FAILED
# Task: SWIR2_2020_04, Status: FAILED
# Task: SWIR2_2020_03, Status: FAILED
# Task: SWIR2_2020_02, Status: FAILED
# Task: SWIR2_2020_01, Status: FAILED
# Task: SWIR2_2019_12, Status: FAILED
# Task: SWIR2_2019_11, Status: FAILED
# Task: SWIR2_2019_10, Status: FAILED
# Task: SWIR2_2019_09, Status: FAILED
# Task: SWIR2_2019_08, Status: FAILED
# Task: SWIR2_2019_07, Status: FAILED
# Task: SWIR2_2019_06, Status: FAILED
# Task: SWIR2_2019_05, Status: FAILED
# Task: SWIR2_2019_04, Status: FAILED
# Task: SWIR2_2019_03, Status: FAILED
# Task: SWIR2_2019_02, Status: FAILED
# Task: SWIR2_2019_01, Status: FAILED
# Task: SWIR2_2018_12, Status: FAILED
# Task: SWIR2_2018_11, Status: FAILED
# Task: SWIR2_2018_10, Status: FAILED
# Task: SWIR2_2018_09, Status: FAILED
# Task: SWIR2_2018_08, Status: FAILED
# Task: SWIR2_2018_07, Status: FAILED
# Task: SWIR2_2018_06, Status: FAILED
# Task: SWIR2_2018_05, Status: FAILED
# Task: SWIR2_2018_04, Status: FAILED
# Task: SWIR2_2018_03, Status: FAILED
# Task: SWIR2_2018_02, Status: FAILED
# Task: SWIR2_2018_01, Status: FAILED
# Task: SWIR2_2017_12, Status: FAILED
# Task: SWIR2_2017_11, Status: FAILED
# Task: SWIR2_2017_10, Status: FAILED
# Task: SWIR2_2017_09, Status: FAILED
# Task: SWIR2_2017_08, Status: FAILED
# Task: SWIR2_2017_07, Status: FAILED
# Task: SWIR2_2017_06, Status: FAILED
# Task: SWIR2_2017_05, Status: FAILED
# Task: SWIR2_2017_04, Status: FAILED
# Task: SWIR2_2017_03, Status: FAILED
# Task: SWIR2_2017_02, Status: FAILED
# Task: SWIR2_2017_01, Status: FAILED
# Task: SWIR2_2016_12, Status: FAILED
# Task: SWIR2_2016_11, Status: FAILED
# Task: SWIR2_2016_10, Status: FAILED
# Task: SWIR2_2016_09, Status: FAILED
# Task: SWIR2_2016_08, Status: FAILED
# Task: SWIR2_2016_07, Status: FAILED
# Task: SWIR2_2016_06, Status: FAILED
# Task: SWIR2_2016_05, Status: FAILED
# Task: SWIR2_2016_04, Status: FAILED
# Task: SWIR2_2016_03, Status: FAILED
# Task: SWIR2_2016_02, Status: FAILED
# Task: SWIR2_2016_01, Status: FAILED
# Task: SWIR2_2015_12, Status: FAILED
# Task: SWIR2_2015_11, Status: FAILED
# Task: SWIR2_2015_10, Status: FAILED
# Task: SWIR2_2015_09, Status: FAILED
# Task: SWIR2_2015_08, Status: FAILED
# Task: SWIR2_2015_07, Status: FAILED
# Task: SWIR2_2015_06, Status: FAILED
# Task: SWIR2_2015_05, Status: FAILED
# Task: SWIR2_2015_04, Status: FAILED
# Task: SWIR2_2015_03, Status: FAILED
# Task: SWIR2_2015_02, Status: FAILED
# Task: SWIR2_2015_01, Status: FAILED
# Task: SWIR2_2014_12, Status: FAILED
# Task: SWIR2_2014_11, Status: FAILED
# Task: SWIR2_2014_10, Status: FAILED
# Task: SWIR2_2014_09, Status: FAILED
# Task: SWIR2_2014_08, Status: FAILED
# Task: SWIR2_2014_07, Status: FAILED
# Task: SWIR2_2014_06, Status: FAILED
# Task: SWIR2_2014_05, Status: FAILED
# Task: SWIR2_2014_04, Status: FAILED
# Task: SWIR2_2014_03, Status: FAILED
# Task: SWIR2_2014_02, Status: FAILED
# Task: SWIR2_2014_01, Status: FAILED
# Task: SWIR2_2013_12, Status: FAILED
# Task: SWIR2_2013_11, Status: FAILED
# Task: SWIR2_2013_10, Status: FAILED
# Task: SWIR2_2013_09, Status: FAILED
# Task: SWIR2_2013_08, Status: FAILED
# Task: SWIR2_2013_07, Status: FAILED
# Task: SWIR2_2013_06, Status: FAILED
# Task: SWIR2_2013_05, Status: FAILED
# Task: SWIR2_2013_04, Status: FAILED
# Task: SWIR2_2013_03, Status: FAILED
# Task: SWIR2_2011_03, Status: FAILED
# Task: SWIR2_2011_02, Status: FAILED
# Task: SWIR2_2011_01, Status: FAILED
# Task: SWIR2_2010_12, Status: FAILED
# Task: SWIR2_2010_05, Status: FAILED
# Task: SWIR2_2010_04, Status: FAILED
# Task: SWIR2_2010_03, Status: FAILED
# Task: SWIR2_2010_02, Status: FAILED
# Task: SWIR2_2010_01, Status: FAILED
# Task: SWIR2_2009_12, Status: FAILED
# Task: SWIR2_2009_11, Status: FAILED
# Task: SWIR2_2009_05, Status: FAILED
# Task: SWIR2_2009_04, Status: FAILED
# Task: SWIR2_2009_03, Status: FAILED
# Task: SWIR2_2008_10, Status: FAILED
# Task: SWIR2_2008_09, Status: FAILED
# Task: SWIR2_2008_08, Status: FAILED
# Task: SWIR2_2008_05, Status: FAILED
# Task: SWIR2_2008_04, Status: FAILED
# Task: SWIR2_2008_03, Status: FAILED
# Task: SWIR2_2008_02, Status: FAILED
# Task: SWIR2_2007_09, Status: FAILED
# Task: SWIR2_2007_08, Status: FAILED
# Task: SWIR2_2007_07, Status: FAILED
# Task: SWIR2_2007_06, Status: FAILED
# Task: SWIR2_2007_05, Status: FAILED
# Task: SWIR2_2007_04, Status: FAILED
# Task: SWIR2_2007_03, Status: FAILED
# Task: SWIR2_2007_02, Status: FAILED
# Task: SWIR2_2007_01, Status: FAILED
# Task: SWIR2_2006_12, Status: FAILED
# Task: SWIR2_2006_11, Status: FAILED
# Task: SWIR2_2006_10, Status: FAILED
# Task: SWIR2_2006_09, Status: FAILED
# Task: SWIR2_2006_08, Status: FAILED
# Task: SWIR2_2006_07, Status: FAILED
# Task: SWIR2_2006_06, Status: FAILED
# Task: SWIR2_2006_04, Status: FAILED
# Task: SWIR2_2006_03, Status: FAILED
# Task: SWIR2_2006_02, Status: FAILED
# Task: SWIR2_2005_11, Status: FAILED
# Task: SWIR2_2005_10, Status: FAILED
# Task: SWIR2_2005_09, Status: FAILED
# Task: SWIR2_2005_08, Status: FAILED
# Task: SWIR2_2005_07, Status: FAILED
# Task: SWIR2_2005_06, Status: FAILED
# Task: SWIR2_2005_04, Status: FAILED
# Task: SWIR2_2005_03, Status: FAILED
# Task: SWIR2_2005_02, Status: FAILED
# Task: SWIR2_2004_09, Status: FAILED
# Task: SWIR2_2004_08, Status: FAILED
# Task: SWIR2_2004_07, Status: FAILED
# Task: SWIR2_2004_06, Status: FAILED
# Task: SWIR2_2004_05, Status: FAILED
# Task: SWIR2_2004_04, Status: FAILED
# Task: SWIR2_2004_03, Status: FAILED
# Task: SWIR2_2004_02, Status: FAILED
# Task: SWIR2_2003_12, Status: FAILED
# Task: SWIR2_2003_11, Status: FAILED
# Task: SWIR2_2003_04, Status: FAILED
# Task: SWIR2_2003_03, Status: FAILED
# Task: SWIR2_2003_02, Status: FAILED
# Task: SWIR2_2003_01, Status: FAILED
# Task: SWIR2_2002_12, Status: FAILED
# Task: SWIR2_2002_11, Status: FAILED
# Task: SWIR2_2002_10, Status: FAILED
# Task: SWIR2_2002_09, Status: FAILED
# Task: SWIR2_2002_08, Status: FAILED
# Task: SWIR2_2002_07, Status: FAILED
# Task: SWIR2_2002_06, Status: FAILED
# Task: SWIR2_2002_05, Status: FAILED
# Task: SWIR2_2002_04, Status: FAILED
# Task: SWIR2_2002_03, Status: FAILED
# Task: SWIR2_2002_02, Status: FAILED
# Task: SWIR2_2002_01, Status: FAILED
# Task: SWIR2_2001_12, Status: FAILED
# Task: SWIR2_2001_11, Status: FAILED
# Task: SWIR2_2001_10, Status: FAILED
# Task: SWIR2_2001_09, Status: FAILED
# Task: SWIR2_2001_08, Status: FAILED
# Task: SWIR2_2001_07, Status: FAILED
# Task: SWIR2_2001_06, Status: FAILED
# Task: SWIR2_2001_04, Status: FAILED
# Task: SWIR2_2001_03, Status: FAILED
# Task: SWIR2_2001_02, Status: FAILED
# Task: SWIR2_2001_01, Status: FAILED
# Task: SWIR2_2000_12, Status: FAILED
# Task: SWIR2_2000_11, Status: FAILED
# Task: SWIR2_2000_10, Status: FAILED
# Task: SWIR2_2000_09, Status: FAILED
# Task: SWIR2_2000_08, Status: FAILED
# Task: SWIR2_2000_07, Status: FAILED
# Task: SWIR2_2000_06, Status: FAILED
# Task: SWIR2_2000_05, Status: FAILED
# Task: SWIR2_2000_04, Status: FAILED
# Task: SWIR2_2000_02, Status: FAILED
# Task: SWIR2_2000_01, Status: FAILED
# Task: SWIR2_1999_12, Status: FAILED
# Task: SWIR2_1999_11, Status: FAILED
# Task: SWIR2_1999_10, Status: FAILED
# Task: SWIR2_1999_08, Status: FAILED
# Task: SWIR2_1999_06, Status: FAILED
# Task: SWIR2_1999_05, Status: FAILED
# Task: SWIR2_1999_04, Status: FAILED
# Task: SWIR2_1999_03, Status: FAILED
# Task: SWIR2_1999_02, Status: FAILED
# Task: SWIR2_1999_01, Status: FAILED
# Task: SWIR2_1998_12, Status: FAILED
# Task: SWIR2_1998_11, Status: FAILED
# Task: SWIR2_1998_10, Status: FAILED
# Task: SWIR2_1998_09, Status: FAILED
# Task: SWIR2_1998_08, Status: FAILED
# Task: SWIR2_1998_07, Status: FAILED
# Task: SWIR2_1998_06, Status: FAILED
# Task: SWIR2_1998_05, Status: FAILED
# Task: SWIR2_1998_04, Status: FAILED
# Task: SWIR2_1998_03, Status: FAILED
# Task: SWIR2_1998_02, Status: FAILED
# Task: SWIR2_1998_01, Status: FAILED
# Task: SWIR2_1997_10, Status: FAILED
# Task: SWIR2_1997_09, Status: FAILED
# Task: SWIR2_1997_08, Status: FAILED
# Task: SWIR2_1997_07, Status: FAILED
# Task: SWIR2_1997_06, Status: FAILED
# Task: SWIR2_1997_04, Status: FAILED
# Task: SWIR2_1997_03, Status: FAILED
# Task: SWIR2_1997_02, Status: FAILED
# Task: SWIR2_1997_01, Status: FAILED
# Task: SWIR2_1996_11, Status: FAILED
# Task: SWIR2_1996_09, Status: FAILED
# Task: SWIR2_1996_08, Status: FAILED
# Task: SWIR2_1996_07, Status: FAILED
# Task: SWIR2_1996_06, Status: FAILED
# Task: SWIR2_1996_03, Status: FAILED
# Task: SWIR2_1996_02, Status: FAILED
# Task: SWIR2_1996_01, Status: FAILED
# Task: SWIR2_1995_12, Status: FAILED
# Task: SWIR2_1995_11, Status: FAILED
# Task: SWIR2_1995_09, Status: FAILED
# Task: SWIR2_1995_08, Status: FAILED
# Task: SWIR2_1995_07, Status: FAILED
# Task: SWIR2_1995_06, Status: FAILED
# Task: SWIR2_1995_05, Status: FAILED
# Task: SWIR2_1995_03, Status: FAILED
# Task: SWIR2_1995_02, Status: FAILED
# Task: SWIR2_1995_01, Status: FAILED
# Task: SWIR2_1994_12, Status: FAILED
# Task: SWIR2_1994_11, Status: FAILED
# Task: SWIR2_1994_10, Status: FAILED
# Task: SWIR2_1994_09, Status: FAILED
# Task: SWIR2_1994_08, Status: FAILED
# Task: SWIR2_1994_07, Status: FAILED
# Task: SWIR2_1994_04, Status: FAILED
# Task: SWIR2_1994_03, Status: FAILED
# Task: SWIR2_1994_01, Status: FAILED
# Task: SWIR2_1993_12, Status: FAILED
# Task: SWIR2_1993_11, Status: FAILED
# Task: SWIR2_1993_08, Status: FAILED
# Task: SWIR2_1993_07, Status: FAILED
# Task: SWIR2_1993_06, Status: FAILED
# Task: SWIR2_1993_05, Status: FAILED
# Task: SWIR2_1993_04, Status: FAILED
# Task: SWIR2_1993_03, Status: FAILED
# Task: SWIR2_1993_02, Status: FAILED
# Task: SWIR2_1993_01, Status: FAILED
# Task: SWIR2_1992_12, Status: FAILED
# Task: SWIR2_1992_11, Status: FAILED
# Task: SWIR2_1992_10, Status: FAILED
# Task: SWIR2_1992_09, Status: FAILED
# Task: SWIR2_1992_08, Status: FAILED
# Task: SWIR2_1992_07, Status: FAILED
# Task: SWIR2_1992_06, Status: FAILED
# Task: SWIR2_1992_05, Status: FAILED
# Task: SWIR2_1992_04, Status: FAILED
# Task: SWIR2_1992_03, Status: FAILED
# Task: SWIR2_1992_02, Status: FAILED
# Task: SWIR2_1992_01, Status: FAILED
# Task: SWIR2_1991_11, Status: FAILED
# Task: SWIR2_1991_10, Status: FAILED
# Task: SWIR2_1991_09, Status: FAILED
# Task: SWIR2_1991_08, Status: FAILED
# Task: SWIR2_1991_07, Status: FAILED
# Task: SWIR2_1991_06, Status: FAILED
# Task: SWIR2_1991_05, Status: FAILED
# Task: SWIR2_1991_04, Status: FAILED
# Task: SWIR2_1991_03, Status: FAILED
# Task: SWIR2_1991_02, Status: FAILED
# Task: SWIR2_1991_01, Status: FAILED
# Task: SWIR2_1990_12, Status: FAILED
# Task: SWIR2_1990_11, Status: FAILED
# Task: SWIR2_1990_10, Status: FAILED
# Task: SWIR2_1990_09, Status: FAILED
# Task: SWIR2_1990_08, Status: FAILED
# Task: SWIR2_1990_07, Status: FAILED
# Task: SWIR2_1990_06, Status: FAILED
# Task: SWIR2_1990_05, Status: FAILED
# Task: SWIR2_1990_04, Status: FAILED
# Task: SWIR2_1990_03, Status: FAILED
# Task: SWIR2_1990_02, Status: FAILED
# Task: SWIR2_1989_12, Status: FAILED
# Task: SWIR2_1989_09, Status: FAILED
# Task: SWIR2_1989_08, Status: FAILED
# Task: SWIR2_1989_07, Status: FAILED
# Task: SWIR2_1989_06, Status: FAILED
# Task: SWIR2_1989_05, Status: FAILED
# Task: SWIR2_1989_04, Status: FAILED
# Task: SWIR2_1989_03, Status: FAILED
# Task: SWIR2_1989_02, Status: FAILED
# Task: SWIR2_1989_01, Status: FAILED
# Task: SWIR2_1987_09, Status: FAILED
# Task: SWIR2_1987_08, Status: FAILED
# Task: SWIR2_1987_07, Status: FAILED
# Task: SWIR2_1987_06, Status: FAILED
# Task: SWIR2_1987_03, Status: FAILED
# Task: SWIR2_1987_02, Status: FAILED
# Task: SWIR2_1987_01, Status: FAILED
# Task: SWIR2_1986_12, Status: FAILED
# Task: SWIR2_1986_11, Status: FAILED
# Task: SWIR2_1985_04, Status: FAILED
# Task: SWIR2_1984_11, Status: FAILED
# Task: SWIR2_1984_10, Status: FAILED
# Task: SWIR2_1984_09, Status: FAILED
# Task: SWIR2_1984_07, Status: FAILED
# Task: SWIR2_1984_06, Status: FAILED
