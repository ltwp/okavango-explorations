# %% [markdown]
# # GEE Asset Wiper
#
# Recursively goes through the targeted GEE folder and deletes all assets within that folder. The folder itself must then be manually deleted within GEE code editor.
#
# ## WARNING!
# This operation is destructive and irreversible — all assets in the folder will be permanently deleted. Use with caution.
#
# Author: James (Huck) Rees, PhD Student, UC Santa Barbara Geography
#
# Date: September 3rd, 2025

# %% [markdown]
# ## Import packages

# %%
import ee
import time

ee.Initialize()

# %% [markdown]
# ## Initialize functions

# %%
def delete_assets_recursively(folder_path):
    """
    Recursively delete all assets (images, tables, folders) within a specified Earth Engine folder.
    
    Args:
        folder_path (str): Full GEE asset path (e.g., 'users/your_username/folder_name')
    """
    def delete_recursive(path):
        try:
            # List assets under the current path
            asset_list = ee.data.listAssets({'parent': path})
            assets = asset_list.get('assets', [])

            for asset in assets:
                asset_id = asset['name']
                asset_type = asset['type']

                # If it's a folder/collection, recurse into it
                if asset_type in ['FOLDER', 'IMAGE_COLLECTION', 'TABLE_COLLECTION']:
                    print(f"📁 Entering folder: {asset_id}")
                    delete_recursive(asset_id)

                # Delete asset
                print(f"🗑️ Deleting asset: {asset_id}")
                ee.data.deleteAsset(asset_id)
                time.sleep(0.5)  # Prevent hitting rate limits

        except Exception as e:
            print(f"❌ Error deleting {path}: {e}")

    print(f"🚀 Starting recursive deletion in: {folder_path}")
    delete_recursive(folder_path)
    print("✅ All assets deleted recursively.")

# %% [markdown]
# ## Enter GEE folder path and run

# %%
GEE_folder_path = "projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products"
delete_assets_recursively(GEE_folder_path)
# Out:
# 🚀 Starting recursive deletion in: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2015_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2016_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Landsat_30m_v3/DSWE_Products/DSWE_2017_12
# ✅ All assets deleted recursively.
