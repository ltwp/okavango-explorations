# %% [markdown]
# # GEE Asset Wiper
#
# Recursively goes through the targeted GEE folder and deletes all assets within that folder. The folder itself must then be manually deleted within GEE code editor.
#
# ## WARNING!
# This operation is destructive and irreversible — all assets in the folder will be permanently deleted. Use with caution.
#
# Author: James (Huck) Rees, PhD Student, UC Santa Barbara Geography
#
# Date: September 3rd, 2025

# %% [markdown]
# ## Import packages

# %%
import ee
import time

ee.Initialize()

# %% [markdown]
# ## Initialize functions

# %%
def delete_assets_recursively(folder_path):
    """
    Recursively delete all assets (images, tables, folders) within a specified Earth Engine folder.
    
    Args:
        folder_path (str): Full GEE asset path (e.g., 'users/your_username/folder_name')
    """
    def delete_recursive(path):
        try:
            # List assets under the current path
            asset_list = ee.data.listAssets({'parent': path})
            assets = asset_list.get('assets', [])

            for asset in assets:
                asset_id = asset['name']
                asset_type = asset['type']

                # If it's a folder/collection, recurse into it
                if asset_type in ['FOLDER', 'IMAGE_COLLECTION', 'TABLE_COLLECTION']:
                    print(f"📁 Entering folder: {asset_id}")
                    delete_recursive(asset_id)

                # Delete asset
                print(f"🗑️ Deleting asset: {asset_id}")
                ee.data.deleteAsset(asset_id)
                time.sleep(0.5)  # Prevent hitting rate limits

        except Exception as e:
            print(f"❌ Error deleting {path}: {e}")

    print(f"🚀 Starting recursive deletion in: {folder_path}")
    delete_recursive(folder_path)
    print("✅ All assets deleted recursively.")

# %% [markdown]
# ## Enter GEE folder path and run

# %%
GEE_folder_path = "projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products"
delete_assets_recursively(GEE_folder_path)
# Out:
# 🚀 Starting recursive deletion in: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2018_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2019_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2020_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2021_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2022_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2023_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_11
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2024_12
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_01
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_02
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_03
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_04
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_05
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_06
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_07
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_08
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_09
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_10
# 🗑️ Deleting asset: projects/ee-okavango/assets/water_masks/monthly_DSWE_Sent2_10m_v3/DSWE_Products/DSWE_2025_11
# ✅ All assets deleted recursively.
